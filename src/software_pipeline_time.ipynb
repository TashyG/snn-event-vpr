# %% [markdown]
# %%% Imports

# %%
from __future__ import annotations
from time import time
from BrisbaneVPRDatasetTime import BrisbaneVPRDatasetTime
from VPRNetwork import VPRNetwork
from plotting import plot_confusion_matrix, plot_match_images, plot_gps
from constants import brisbane_event_traverses, brisbane_event_traverses_aliases
from utils import get_short_traverse_name

import os, sys
import torch
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from matplotlib import animation
from scipy import signal
from datetime import datetime

import numpy as np

import lava.lib.dl.slayer as slayer
from lava.lib.dl.slayer.classifier import Rate

# %%
# Training settings
from cgi import test


epochs = 50
batch_size = 10

# Network settings
input_size = 34
threshold = 1.0

# Data settings
train_traverse = brisbane_event_traverses[0]
test_traverse = brisbane_event_traverses[2]
train_name = brisbane_event_traverses_aliases[get_short_traverse_name(train_traverse)]
test_name = brisbane_event_traverses_aliases[get_short_traverse_name(test_traverse)]
num_places = 16
start_dist = 3200
place_gap = 50 #164/num_places # The streams run for approximately 164 seconds 
samples_per_sec = 1000
place_duration = 2
max_spikes = None

# Sequencer settings
sequence_length = 3

# Plot settings
redo_plot = False
vmin = 0
vmax = 0.05

def transpose( matrix):
    if len(matrix) == 0:
        return []
    return [[matrix[i][j] for i in range(len(matrix))] for j in range(len(matrix[0]))]


# Make a folder for the trained network
trained_folder = 'Trained'
os.makedirs(trained_folder, exist_ok=True)

# Use GPU
print(torch.cuda.is_available())
device = torch.device('cuda')

#---------------- Create the Network -----------------#

# Create the network
net = VPRNetwork(input_size, num_places, threshold=threshold).to(device)
# Out:
# True

# %%
# Load the data
training_set = BrisbaneVPRDatasetTime(train_traverse, train=True, place_duration = place_duration, place_gap=place_gap, num_places=num_places, start_dist=start_dist,samples_per_sec=samples_per_sec, max_spikes=max_spikes)
testing_set  = BrisbaneVPRDatasetTime(test_traverse, train=False, place_duration = place_duration, training_locations=training_set.place_locations, place_gap=place_gap, num_places=num_places, start_dist=start_dist, samples_per_sec=samples_per_sec, max_spikes=max_spikes)
            
train_loader = DataLoader(dataset=training_set, batch_size=batch_size, shuffle=True)
test_loader  = DataLoader(dataset=testing_set , batch_size=batch_size, shuffle=True)
# Out:
# Loading training event streams ...
# Adding GPS
# Duration: 527.16s (which is 3432338 events)
# Distance: 6308.49m (which is 3432338 events)
# /home/n10223622/snn-event-vpr/src/BrisbaneVPRDatasetTime.py:206: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chopped_stream['t'] -= chop_start
# Place: 0
# Distance: 32.17m (which is 16925 events)
# Place: 1
# Distance: 31.44m (which is 16438 events)
# Place: 2
# Distance: 31.32m (which is 29244 events)
# Place: 3
# Distance: 31.33m (which is 10253 events)
# Place: 4
# Distance: 30.02m (which is 18011 events)
# Place: 5
# Distance: 24.89m (which is 10613 events)
# Place: 6
# Distance: 23.15m (which is 11257 events)
# Place: 7
# Distance: 21.03m (which is 10016 events)
# Place: 8
# Distance: 9.41m (which is 8450 events)
# Place: 9
# Distance: 16.56m (which is 6508 events)
# Place: 10
# Distance: 19.72m (which is 7151 events)
# Place: 11
# Distance: 13.15m (which is 12577 events)
# Place: 12
# Distance: 6.57m (which is 5243 events)
# Place: 13
# Distance: 24.02m (which is 9181 events)
# Place: 14
# Distance: 27.30m (which is 7425 events)
# Place: 15
# Distance: 28.74m (which is 3465 events)
# The number of training substreams is: 16
# Loading testing event streams ...
# Adding GPS
# Duration: 516.16s (which is 3442353 events)
# Distance: 6023.50m (which is 3442353 events)
# Place: 0
# Distance: 29.51m (which is 24010 events)
# Place: 1
# Distance: 20.45m (which is 18518 events)
# Place: 2
# Distance: 14.08m (which is 2331 events)
# Place: 3
# Distance: 10.64m (which is 5633 events)
# Place: 4
# Distance: 9.05m (which is 18964 events)
# Place: 5
# Distance: 14.86m (which is 4648 events)
# Place: 6
# Distance: 15.90m (which is 14506 events)
# Place: 7
# Distance: 15.77m (which is 7724 events)
# Place: 8
# Distance: 17.03m (which is 16839 events)
# Place: 9
# Distance: 17.17m (which is 12779 events)
# Place: 10
# Distance: 12.76m (which is 5166 events)
# Place: 11
# Distance: 3.10m (which is 3879 events)
# Place: 12
# Distance: 18.61m (which is 8111 events)
# Place: 13
# Distance: 22.52m (which is 3875 events)
# Place: 14
# Distance: 26.55m (which is 2714 events)
# Place: 15
# Distance: 27.85m (which is 3191 events)
# The number of testing substreams is: 16
# /home/n10223622/snn-event-vpr/src/BrisbaneVPRDatasetTime.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chopped_stream['t'] -= chop_start

# %%
# Define an optimiser 
optimizer = torch.optim.Adam(net.parameters(), lr=0.001)

# Training the network
error = slayer.loss.SpikeRate(true_rate=0.2, false_rate=0.03, reduction='sum').to(device)

# Create a training assistant object
stats = slayer.utils.LearningStats()
assistant = slayer.utils.Assistant(net, error, optimizer, stats, classifier=slayer.classifier.Rate.predict)


if redo_plot:
    for i, (input, label) in enumerate(train_loader): # training loop
        output = assistant.train(input, label)

else: 
    for epoch in range(epochs):

        for i, (input, label) in enumerate(train_loader): # training loop
            output = assistant.train(input, label)
        print(f'\r[Epoch {epoch:2d}/{epochs}] {stats}', end='')

        for i, (input, label) in enumerate(test_loader): # training loop
            output = assistant.test(input, label)
        print(f'\r[Epoch {epoch:2d}/{epochs}] {stats}', end='')

        if epoch%20 == 19: # cleanup display
            print('\r', ' '*len(f'\r[Epoch {epoch:2d}/{epochs}] {stats}'))
            stats_str = str(stats).replace("| ", "\n")
            print(f'[Epoch {epoch:2d}/{epochs}]\n{stats_str}')

        if stats.testing.best_accuracy:
            torch.save(net.state_dict(), trained_folder + '/network.pt')
        stats.update()
        stats.save(trained_folder + '/')
        net.grad_flow(trained_folder + '/')
# Out:
# [Epoch  0/50] Train loss =     0.84884                        accuracy = 0.06250 | Test  loss =     0.43413                        accuracy = 0.12500
# Accuracy was none
# [Epoch  1/50] Train loss =     0.32466 (min =     0.84884)    accuracy = 0.43750 (max = 0.06250) | Test  loss =     0.38802 (min =     0.43413)    accuracy = 0.18750 (max = 0.12500)
# Accuracy was none
# [Epoch  2/50] Train loss =     0.29619 (min =     0.32466)    accuracy = 0.81250 (max = 0.43750) | Test  loss =     0.38904 (min =     0.38802)    accuracy = 0.06250 (max = 0.18750)
# Accuracy was none
# [Epoch  3/50] Train loss =     0.24651 (min =     0.29619)    accuracy = 0.68750 (max = 0.81250) | Test  loss =     0.37395 (min =     0.38802)    accuracy = 0.25000 (max = 0.18750)
# Accuracy was none
# [Epoch  4/50] Train loss =     0.19223 (min =     0.24651)    accuracy = 0.81250 (max = 0.81250) | Test  loss =     0.42974 (min =     0.37395)    accuracy = 0.25000 (max = 0.25000)
# Accuracy was none
# [Epoch  5/50] Train loss =     0.24209 (min =     0.19223)    accuracy = 0.87500 (max = 0.81250) | Test  loss =     0.42548 (min =     0.37395)    accuracy = 0.18750 (max = 0.25000)
# Accuracy was none
# [Epoch  6/50] Train loss =     0.17623 (min =     0.19223)    accuracy = 0.87500 (max = 0.87500) | Test  loss =     0.42292 (min =     0.37395)    accuracy = 0.12500 (max = 0.25000)
# Accuracy was none
# [Epoch  7/50] Train loss =     0.14479 (min =     0.17623)    accuracy = 0.87500 (max = 0.87500) | Test  loss =     0.43304 (min =     0.37395)    accuracy = 0.18750 (max = 0.25000)
# Accuracy was none
# [Epoch  8/50] Train loss =     0.12143 (min =     0.14479)    accuracy = 0.93750 (max = 0.87500) | Test  loss =     0.43636 (min =     0.37395)    accuracy = 0.25000 (max = 0.25000)
# Accuracy was none
# [Epoch  9/50] Train loss =     0.08030 (min =     0.12143)    accuracy = 0.93750 (max = 0.93750) | Test  loss =     0.40808 (min =     0.37395)    accuracy = 0.25000 (max = 0.25000)
# Accuracy was none
# [Epoch 10/50] Train loss =     0.09122 (min =     0.08030)    accuracy = 0.93750 (max = 0.93750) | Test  loss =     0.48168 (min =     0.37395)    accuracy = 0.37500 (max = 0.25000)
# Accuracy was none
# [Epoch 11/50] Train loss =     0.08745 (min =     0.08030)    accuracy = 1.00000 (max = 0.93750) | Test  loss =     0.46526 (min =     0.37395)    accuracy = 0.18750 (max = 0.37500)
# Accuracy was none
# [Epoch 12/50] Train loss =     0.06902 (min =     0.08030)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.47981 (min =     0.37395)    accuracy = 0.12500 (max = 0.37500)
# Accuracy was none
# [Epoch 13/50] Train loss =     0.05458 (min =     0.06902)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.46519 (min =     0.37395)    accuracy = 0.18750 (max = 0.37500)
# Accuracy was none
# [Epoch 14/50] Train loss =     0.05370 (min =     0.05458)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.42458 (min =     0.37395)    accuracy = 0.18750 (max = 0.37500)
# Accuracy was none
# [Epoch 15/50] Train loss =     0.04703 (min =     0.05370)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.44144 (min =     0.37395)    accuracy = 0.06250 (max = 0.37500)
# Accuracy was none
# [Epoch 16/50] Train loss =     0.03939 (min =     0.04703)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.43485 (min =     0.37395)    accuracy = 0.12500 (max = 0.37500)
# Accuracy was none
# [Epoch 17/50] Train loss =     0.03866 (min =     0.03939)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.44300 (min =     0.37395)    accuracy = 0.12500 (max = 0.37500)
# Accuracy was none
# [Epoch 18/50] Train loss =     0.03885 (min =     0.03866)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.45766 (min =     0.37395)    accuracy = 0.12500 (max = 0.37500)
# Accuracy was none
#
# [Epoch 19/50]
# Train loss =     0.03294 (min =     0.03866)    accuracy = 1.00000 (max = 1.00000)
# Test  loss =     0.43259 (min =     0.37395)    accuracy = 0.12500 (max = 0.37500)
#
# Accuracy was none
# [Epoch 20/50] Train loss =     0.02668 (min =     0.03294)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.44695 (min =     0.37395)    accuracy = 0.06250 (max = 0.37500)
# Accuracy was none
# [Epoch 21/50] Train loss =     0.03090 (min =     0.02668)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.41007 (min =     0.37395)    accuracy = 0.06250 (max = 0.37500)
# Accuracy was none
# [Epoch 22/50] Train loss =     0.02871 (min =     0.02668)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.41350 (min =     0.37395)    accuracy = 0.06250 (max = 0.37500)
# Accuracy was none
# [Epoch 23/50] Train loss =     0.01986 (min =     0.02668)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.46545 (min =     0.37395)    accuracy = 0.06250 (max = 0.37500)
# Accuracy was none
# [Epoch 24/50] Train loss =     0.02121 (min =     0.01986)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.44619 (min =     0.37395)    accuracy = 0.06250 (max = 0.37500)
# Accuracy was none
# [Epoch 25/50] Train loss =     0.02048 (min =     0.01986)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.43051 (min =     0.37395)    accuracy = 0.12500 (max = 0.37500)
# Accuracy was none
# [Epoch 26/50] Train loss =     0.01652 (min =     0.01986)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.43955 (min =     0.37395)    accuracy = 0.25000 (max = 0.37500)
# Accuracy was none
# [Epoch 27/50] Train loss =     0.01659 (min =     0.01652)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.41338 (min =     0.37395)    accuracy = 0.18750 (max = 0.37500)
# Accuracy was none
# [Epoch 28/50] Train loss =     0.01567 (min =     0.01652)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.49547 (min =     0.37395)    accuracy = 0.12500 (max = 0.37500)
# Accuracy was none
# [Epoch 29/50] Train loss =     0.01766 (min =     0.01567)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.42433 (min =     0.37395)    accuracy = 0.12500 (max = 0.37500)
# Accuracy was none
# [Epoch 30/50] Train loss =     0.01633 (min =     0.01567)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.40919 (min =     0.37395)    accuracy = 0.18750 (max = 0.37500)
# Accuracy was none
# [Epoch 31/50] Train loss =     0.01630 (min =     0.01567)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.41115 (min =     0.37395)    accuracy = 0.18750 (max = 0.37500)
# Accuracy was none
# [Epoch 32/50] Train loss =     0.01584 (min =     0.01567)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.43125 (min =     0.37395)    accuracy = 0.12500 (max = 0.37500)
# Accuracy was none
# [Epoch 33/50] Train loss =     0.01480 (min =     0.01567)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.44524 (min =     0.37395)    accuracy = 0.06250 (max = 0.37500)
# Accuracy was none
# [Epoch 34/50] Train loss =     0.01521 (min =     0.01480)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.44979 (min =     0.37395)    accuracy = 0.06250 (max = 0.37500)
# Accuracy was none
# [Epoch 35/50] Train loss =     0.01410 (min =     0.01480)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.45896 (min =     0.37395)    accuracy = 0.12500 (max = 0.37500)
# Accuracy was none
# [Epoch 36/50] Train loss =     0.01535 (min =     0.01410)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.44165 (min =     0.37395)    accuracy = 0.12500 (max = 0.37500)
# Accuracy was none
# [Epoch 37/50] Train loss =     0.01020 (min =     0.01410)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.42997 (min =     0.37395)    accuracy = 0.06250 (max = 0.37500)
# Accuracy was none
# [Epoch 38/50] Train loss =     0.01447 (min =     0.01020)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.39109 (min =     0.37395)    accuracy = 0.06250 (max = 0.37500)
# Accuracy was none
#
# [Epoch 39/50]
# Train loss =     0.01400 (min =     0.01020)    accuracy = 1.00000 (max = 1.00000)
# Test  loss =     0.43581 (min =     0.37395)    accuracy = 0.06250 (max = 0.37500)
#
# Accuracy was none
# [Epoch 40/50] Train loss =     0.01499 (min =     0.01020)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.38249 (min =     0.37395)    accuracy = 0.18750 (max = 0.37500)
# Accuracy was none
# [Epoch 41/50] Train loss =     0.01235 (min =     0.01020)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.44015 (min =     0.37395)    accuracy = 0.12500 (max = 0.37500)
# Accuracy was none
# [Epoch 42/50] Train loss =     0.01233 (min =     0.01020)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.41877 (min =     0.37395)    accuracy = 0.18750 (max = 0.37500)
# Accuracy was none
# [Epoch 43/50] Train loss =     0.01170 (min =     0.01020)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.47365 (min =     0.37395)    accuracy = 0.12500 (max = 0.37500)
# Accuracy was none
# [Epoch 44/50] Train loss =     0.01091 (min =     0.01020)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.45912 (min =     0.37395)    accuracy = 0.06250 (max = 0.37500)
# Accuracy was none
# [Epoch 45/50] Train loss =     0.01447 (min =     0.01020)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.44360 (min =     0.37395)    accuracy = 0.12500 (max = 0.37500)
# Accuracy was none
# [Epoch 46/50] Train loss =     0.01186 (min =     0.01020)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.40677 (min =     0.37395)    accuracy = 0.12500 (max = 0.37500)
# Accuracy was none
# [Epoch 47/50] Train loss =     0.01355 (min =     0.01020)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.47560 (min =     0.37395)    accuracy = 0.12500 (max = 0.37500)
# Accuracy was none
# [Epoch 48/50] Train loss =     0.01043 (min =     0.01020)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.39604 (min =     0.37395)    accuracy = 0.06250 (max = 0.37500)
# Accuracy was none
# [Epoch 49/50] Train loss =     0.01041 (min =     0.01020)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.40598 (min =     0.37395)    accuracy = 0.12500 (max = 0.37500)
# Accuracy was none

# %%
# import the best network during training 
net.load_state_dict(torch.load(trained_folder + '/network.pt'))
net.export_hdf5(trained_folder + '/network.net')

# Get the output for the input to each place
test_loader2  = DataLoader(dataset=testing_set , batch_size=batch_size, shuffle=False)
rate = []
labels = []
for i, (input, label) in enumerate(test_loader2):
    output = net(input.to(device)) # Get network output
    #guesses = assistant.classifier(output).cpu().data.numpy() # get the predictions 
    rate.extend(Rate.rate(output).cpu().data.numpy()) # Get the firing rates for each place 
    labels.extend(label.cpu().data.numpy()) # Get place labels


# # Get rates in percentages of total
# for i in range(num_places):
#     sum = np.sum(rate[i])
#     if sum != 0:
#         rate[i] = np.divide(rate[i],sum)

# Make confusion matrix annotations
accuracy = 0
matches = []
annotations = [['' for i in range(num_places)] for j in range(num_places)]
for qryIndex in range(num_places):
    max_idx = np.argmax(rate[qryIndex])
    matches.append(max_idx)
    annotations[max_idx][qryIndex] = 'x'
    if max_idx ==qryIndex:
        accuracy += 1


#--------------- Apply a sequencer ------------------#
I = np.identity(sequence_length)
conv = signal.convolve2d(rate, I, mode='same')
print(np.shape(conv))

# Make confusion matrix annotations
accuracy_s = 0
matches_with_seq = []
annotations_s = [['' for i in range(num_places)] for j in range(num_places)]
for qryIndex in range(num_places):
    max_idx = np.argmax(conv[qryIndex])
    matches_with_seq.append(max_idx)
    annotations_s[max_idx][qryIndex] = 'x'
    if max_idx == qryIndex:
        accuracy_s += 1
# Out:
# (16, 16)

# %%
#--------------- Save Results ------------------#

# Make new folder for results
from tracemalloc import start
from plotting import plot_gps


time_stamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
results_path = "./../results/" + time_stamp
os.mkdir(results_path)


# Save query and match images 
images_path = results_path + "/matched_images"
images_path_seq = results_path + "/matched_images_seq"
os.mkdir(images_path)
os.mkdir(images_path_seq)

print('help')
plot_match_images(images_path + "/", matches, training_set.place_images, testing_set.place_images)
plot_match_images(images_path_seq + "/", matches_with_seq, training_set.place_images, testing_set.place_images)

# Save the confusion matrices
confusion_path = results_path + "/confusion_matrices"
os.mkdir(confusion_path)
rate = transpose(rate)
conv = transpose(conv)
output_path = confusion_path + "/confusion_matrix" 
output_path_s = confusion_path + "/confusion_matrix_seq" 
plot_confusion_matrix(rate, labels, annotations, output_path, vmin, vmax)
plot_confusion_matrix(conv, labels, annotations_s, output_path_s, vmin, vmax)

# Save GPS map'
gps_path = results_path + "/gps_locations"
plot_gps(gps_path, training_set.place_locations, testing_set.place_locations)

# Save test settings and accuracy
accuracy = accuracy/num_places
accuracy_s = accuracy_s/num_places
# Out:
# help

# %%
log_path = results_path + "/log.txt"
log_string  = """
---- DATA SETTINGS ---- 
Training datasets = {}
Testing datasets = {} 
# Places = {}
Start dist = {} [m]
Place gap = {} [m]
Place duration = {} [s]
Samples per second = {} 
Max spikes per sample = {}
---- NETWORK SETTINGS ---- 
Input size = {}x{} 
Threshold = {}
---- TRAINING SETTINGS ---- 
Epochs = {}
Batch size = {}
---- SEQUENCER SETTINGS ----
Sequence lengtth = {} 
---- RESULTS ----
Accuracy = {}
Accuracy (sequencer) = {}
""".format(train_name,test_name,num_places,start_dist,place_gap,place_duration,
                samples_per_sec,max_spikes,input_size,input_size,threshold,epochs,
                batch_size,sequence_length,accuracy,accuracy_s)
f = open(log_path,'w')
f.write(log_string)
f.close()

print("The accuracy of the network is: " + str(accuracy))
print("The accuracy with a sequencer is: " + str(accuracy_s))
# Out:
# The accuracy of the network is: 0.1875
# The accuracy with a sequencer is: 0.4375
