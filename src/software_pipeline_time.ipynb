# %% [markdown]
# %%% Imports

# %%
from __future__ import annotations
from time import time
from BrisbaneVPRDatasetTime import BrisbaneVPRDatasetTime
from VPRNetwork import VPRNetwork
from plotting import plot_confusion_matrix, plot_match_images, plot_gps
from constants import brisbane_event_traverses, brisbane_event_traverses_aliases
from utils import get_short_traverse_name

import os, sys
import torch
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from matplotlib import animation
from scipy import signal
from datetime import datetime

import numpy as np

import lava.lib.dl.slayer as slayer
from lava.lib.dl.slayer.classifier import Rate

# %%
# Training settings
from cgi import test


epochs = 50
batch_size = 10

# Network settings
input_size = 34
threshold = 1.0

# Data settings
train_traverse = brisbane_event_traverses[0]
test_traverse = brisbane_event_traverses[2]
train_name = brisbane_event_traverses_aliases[get_short_traverse_name(train_traverse)]
test_name = brisbane_event_traverses_aliases[get_short_traverse_name(test_traverse)]
num_places = 45
start_dist = 200
place_gap = 100 #164/num_places # The streams run for approximately 164 seconds 
samples_per_sec = 1000
place_duration = 2
max_spikes = None

# Sequencer settings
sequence_length = 3

# Plot settings
redo_plot = False
vmin = 0
vmax = 0.05

def transpose( matrix):
    if len(matrix) == 0:
        return []
    return [[matrix[i][j] for i in range(len(matrix))] for j in range(len(matrix[0]))]


# Make a folder for the trained network
trained_folder = 'Trained'
os.makedirs(trained_folder, exist_ok=True)

# Use GPU
print(torch.cuda.is_available())
device = torch.device('cuda')

#---------------- Create the Network -----------------#

# Create the network
net = VPRNetwork(input_size, num_places, threshold=threshold).to(device)
# Out:
# True

# %%
# Load the data
training_set = BrisbaneVPRDatasetTime(train_traverse, train=True, place_duration = place_duration, place_gap=place_gap, num_places=num_places, start_dist=start_dist,samples_per_sec=samples_per_sec, max_spikes=max_spikes)
testing_set  = BrisbaneVPRDatasetTime(test_traverse, train=False, place_duration = place_duration, training_locations=training_set.place_locations, place_gap=place_gap, num_places=num_places, start_dist=start_dist, samples_per_sec=samples_per_sec, max_spikes=max_spikes)
            
train_loader = DataLoader(dataset=training_set, batch_size=batch_size, shuffle=True)
test_loader  = DataLoader(dataset=testing_set , batch_size=batch_size, shuffle=True)
# Out:
# Loading training event streams ...
# Adding GPS
# Duration: 527.16s (which is 3432338 events)
# Distance: 6308.49m (which is 3432338 events)
# Place: 0
# Distance: 27.09m (which is 16831 events)
# /home/n10223622/snn-event-vpr/src/BrisbaneVPRDatasetTime.py:206: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chopped_stream['t'] -= chop_start
# Place: 1
# Distance: 22.37m (which is 11571 events)
# Place: 2
# Distance: 24.62m (which is 6218 events)
# Place: 3
# Distance: 25.05m (which is 11757 events)
# Place: 4
# Distance: 25.69m (which is 16353 events)
# Place: 5
# Distance: 26.19m (which is 10336 events)
# Place: 6
# Distance: 25.29m (which is 9351 events)
# Place: 7
# Distance: 14.78m (which is 13630 events)
# Place: 8
# Distance: 25.71m (which is 19693 events)
# Place: 9
# Distance: 26.06m (which is 19902 events)
# Place: 10
# Distance: 29.38m (which is 20254 events)
# Place: 11
# Distance: 30.70m (which is 19454 events)
# Place: 12
# Distance: 30.11m (which is 25099 events)
# Place: 13
# Distance: 30.32m (which is 31980 events)
# Place: 14
# Distance: 30.67m (which is 31916 events)
# Place: 15
# Distance: 30.15m (which is 20344 events)
# Place: 16
# Distance: 26.11m (which is 13738 events)
# Place: 17
# Distance: 26.72m (which is 5523 events)
# Place: 18
# Distance: 35.03m (which is 8125 events)
# Place: 19
# Distance: 34.11m (which is 6218 events)
# Place: 20
# Distance: 34.72m (which is 2781 events)
# Place: 21
# Distance: 34.94m (which is 2556 events)
# Place: 22
# Distance: 31.86m (which is 2479 events)
# Place: 23
# Distance: 27.06m (which is 5047 events)
# Place: 24
# Distance: 24.74m (which is 1313 events)
# Place: 25
# Distance: 31.07m (which is 7835 events)
# Place: 26
# Distance: 28.69m (which is 16315 events)
# Place: 27
# Distance: 28.37m (which is 8889 events)
# Place: 28
# Distance: 30.50m (which is 15303 events)
# Place: 29
# Distance: 29.82m (which is 19846 events)
# Place: 30
# Distance: 32.17m (which is 16925 events)
# Place: 31
# Distance: 31.32m (which is 29244 events)
# Place: 32
# Distance: 30.02m (which is 18011 events)
# Place: 33
# Distance: 23.15m (which is 11257 events)
# Place: 34
# Distance: 9.41m (which is 8450 events)
# Place: 35
# Distance: 19.72m (which is 7151 events)
# Place: 36
# Distance: 6.57m (which is 5243 events)
# Place: 37
# Distance: 27.30m (which is 7425 events)
# Place: 38
# Distance: 28.22m (which is 15030 events)
# Place: 39
# Distance: 29.24m (which is 11479 events)
# Place: 40
# Distance: 30.27m (which is 26435 events)
# Place: 41
# Distance: 30.40m (which is 23262 events)
# Place: 42
# Distance: 29.91m (which is 26455 events)
# Place: 43
# Distance: 29.23m (which is 12309 events)
# Place: 44
# Distance: 28.12m (which is 27836 events)
# The number of training substreams is: 45
# Loading testing event streams ...
# Adding GPS
# Duration: 516.16s (which is 3442353 events)
# Distance: 6023.50m (which is 3442353 events)
# Place: 0
# Distance: 29.49m (which is 20846 events)
# Place: 1
# Distance: 22.28m (which is 14344 events)
# Place: 2
# Distance: 23.83m (which is 6259 events)
# Place: 3
# Distance: 26.10m (which is 16077 events)
# Place: 4
# Distance: 27.89m (which is 15579 events)
# Place: 5
# Distance: 29.73m (which is 14459 events)
# Place: 6
# Distance: 27.65m (which is 18601 events)
# Place: 7
# Distance: 14.84m (which is 18188 events)
# Place: 8
# Distance: 27.50m (which is 21237 events)
# Place: 9
# Distance: 29.98m (which is 23725 events)
# Place: 10
# Distance: 32.40m (which is 26080 events)
# Place: 11
# Distance: 31.56m (which is 23729 events)
# Place: 12
# Distance: 30.88m (which is 26314 events)
# Place: 13
# Distance: 29.45m (which is 26300 events)
# Place: 14
# Distance: 31.69m (which is 32463 events)
# Place: 15
# Distance: 30.38m (which is 19451 events)
# Place: 16
# Distance: 28.04m (which is 19098 events)
# Place: 17
# Distance: 27.32m (which is 2197 events)
# Place: 18
# Distance: 34.35m (which is 10415 events)
# /home/n10223622/snn-event-vpr/src/BrisbaneVPRDatasetTime.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chopped_stream['t'] -= chop_start
# Place: 19
# Distance: 33.06m (which is 7652 events)
# Place: 20
# Distance: 31.54m (which is 4713 events)
# Place: 21
# Distance: 32.30m (which is 4041 events)
# Place: 22
# Distance: 32.49m (which is 3602 events)
# Place: 23
# Distance: 33.54m (which is 10000 events)
# Place: 24
# Distance: 33.09m (which is 4892 events)
# Place: 25
# Distance: 31.64m (which is 9742 events)
# Place: 26
# Distance: 29.66m (which is 23734 events)
# Place: 27
# Distance: 29.10m (which is 15803 events)
# Place: 28
# Distance: 29.89m (which is 22525 events)
# Place: 29
# Distance: 30.56m (which is 20964 events)
# Place: 30
# Distance: 29.51m (which is 24010 events)
# Place: 31
# Distance: 14.08m (which is 2331 events)
# Place: 32
# Distance: 9.05m (which is 18964 events)
# Place: 33
# Distance: 15.90m (which is 14506 events)
# Place: 34
# Distance: 17.03m (which is 16839 events)
# Place: 35
# Distance: 12.76m (which is 5166 events)
# Place: 36
# Distance: 18.61m (which is 8111 events)
# Place: 37
# Distance: 26.55m (which is 2714 events)
# Place: 38
# Distance: 28.57m (which is 28658 events)
# Place: 39
# Distance: 29.72m (which is 4182 events)
# Place: 40
# Distance: 31.24m (which is 38866 events)
# Place: 41
# Distance: 30.29m (which is 6705 events)
# Place: 42
# Distance: 29.76m (which is 34413 events)
# Place: 43
# Distance: 28.89m (which is 2594 events)
# Place: 44
# Distance: 28.15m (which is 32705 events)
# The number of testing substreams is: 45

# %%
# Define an optimiser 
optimizer = torch.optim.Adam(net.parameters(), lr=0.001)

# Training the network
error = slayer.loss.SpikeRate(true_rate=0.2, false_rate=0.03, reduction='sum').to(device)

# Create a training assistant object
stats = slayer.utils.LearningStats()
assistant = slayer.utils.Assistant(net, error, optimizer, stats, classifier=slayer.classifier.Rate.predict)


if redo_plot:
    for i, (input, label) in enumerate(train_loader): # training loop
        output = assistant.train(input, label)

else: 
    for epoch in range(epochs):

        for i, (input, label) in enumerate(train_loader): # training loop
            output = assistant.train(input, label)
        print(f'\r[Epoch {epoch:2d}/{epochs}] {stats}', end='')

        for i, (input, label) in enumerate(test_loader): # training loop
            output = assistant.test(input, label)
        print(f'\r[Epoch {epoch:2d}/{epochs}] {stats}', end='')

        if epoch%20 == 19: # cleanup display
            print('\r', ' '*len(f'\r[Epoch {epoch:2d}/{epochs}] {stats}'))
            stats_str = str(stats).replace("| ", "\n")
            print(f'[Epoch {epoch:2d}/{epochs}]\n{stats_str}')

        if stats.testing.best_accuracy:
            torch.save(net.state_dict(), trained_folder + '/network.pt')
        stats.update()
        stats.save(trained_folder + '/')
        net.grad_flow(trained_folder + '/')
# Out:
# [Epoch  0/50] Train loss =     1.33224 | Test  loss =     0.72341                        accuracy = 0.04444
# Accuracy was none
#
# Accuracy was none
# [Epoch  1/50] Train loss =     0.69279 (min =     1.33224)    accuracy = 0.02222  | Test  loss =     1.01581 (min =     0.72341)    accuracy = 0.02222 (max = 0.04444)
# Accuracy was none
# [Epoch  2/50] Train loss =     0.63532 (min =     0.69279)    accuracy = 0.13333 (max = 0.02222) | Test  loss =     0.94488 (min =     0.72341)    accuracy = 0.04444 (max = 0.04444)
# Accuracy was none
# [Epoch  3/50] Train loss =     0.54427 (min =     0.63532)    accuracy = 0.13333 (max = 0.13333) | Test  loss =     1.19499 (min =     0.72341)    accuracy = 0.04444 (max = 0.04444)
# Accuracy was none
# [Epoch  4/50] Train loss =     0.46451 (min =     0.54427)    accuracy = 0.22222 (max = 0.13333) | Test  loss =     1.44894 (min =     0.72341)    accuracy = 0.04444 (max = 0.04444)
# Accuracy was none
# [Epoch  5/50] Train loss =     0.44990 (min =     0.46451)    accuracy = 0.31111 (max = 0.22222) | Test  loss =     1.33089 (min =     0.72341)    accuracy = 0.06667 (max = 0.04444)
# Accuracy was none
# [Epoch  6/50] Train loss =     0.44401 (min =     0.44990)    accuracy = 0.31111 (max = 0.31111) | Test  loss =     1.54252 (min =     0.72341)    accuracy = 0.02222 (max = 0.06667)
# Accuracy was none
# [Epoch  7/50] Train loss =     0.36917 (min =     0.44401)    accuracy = 0.37778 (max = 0.31111) | Test  loss =     2.10573 (min =     0.72341)    accuracy = 0.06667 (max = 0.06667)
# Accuracy was none
# [Epoch  8/50] Train loss =     0.36465 (min =     0.36917)    accuracy = 0.51111 (max = 0.37778) | Test  loss =     1.87879 (min =     0.72341)    accuracy = 0.04444 (max = 0.06667)
# Accuracy was none
# [Epoch  9/50] Train loss =     0.34357 (min =     0.36465)    accuracy = 0.57778 (max = 0.51111) | Test  loss =     1.95898 (min =     0.72341)    accuracy = 0.08889 (max = 0.06667)
# Accuracy was none
# [Epoch 10/50] Train loss =     0.31750 (min =     0.34357)    accuracy = 0.64444 (max = 0.57778) | Test  loss =     1.49558 (min =     0.72341)    accuracy = 0.13333 (max = 0.08889)
# Accuracy was none
# [Epoch 11/50] Train loss =     0.28383 (min =     0.31750)    accuracy = 0.75556 (max = 0.64444) | Test  loss =     1.54550 (min =     0.72341)    accuracy = 0.11111 (max = 0.13333)
# Accuracy was none
# [Epoch 12/50] Train loss =     0.26558 (min =     0.28383)    accuracy = 0.80000 (max = 0.75556) | Test  loss =     2.39017 (min =     0.72341)    accuracy = 0.13333 (max = 0.13333)
# Accuracy was none
# [Epoch 13/50] Train loss =     0.25282 (min =     0.26558)    accuracy = 0.84444 (max = 0.80000) | Test  loss =     1.57915 (min =     0.72341)    accuracy = 0.15556 (max = 0.13333)
# Accuracy was none
# [Epoch 14/50] Train loss =     0.25001 (min =     0.25282)    accuracy = 0.71111 (max = 0.84444) | Test  loss =     2.72769 (min =     0.72341)    accuracy = 0.15556 (max = 0.15556)
# Accuracy was none
# [Epoch 15/50] Train loss =     0.24537 (min =     0.25001)    accuracy = 0.88889 (max = 0.84444) | Test  loss =     2.30019 (min =     0.72341)    accuracy = 0.13333 (max = 0.15556)
# Accuracy was none
# [Epoch 16/50] Train loss =     0.23183 (min =     0.24537)    accuracy = 0.91111 (max = 0.88889) | Test  loss =     1.66325 (min =     0.72341)    accuracy = 0.15556 (max = 0.15556)
# Accuracy was none
# [Epoch 17/50] Train loss =     0.20683 (min =     0.23183)    accuracy = 0.91111 (max = 0.91111) | Test  loss =     1.76734 (min =     0.72341)    accuracy = 0.11111 (max = 0.15556)
# Accuracy was none
# [Epoch 18/50] Train loss =     0.19774 (min =     0.20683)    accuracy = 0.91111 (max = 0.91111) | Test  loss =     1.75859 (min =     0.72341)    accuracy = 0.20000 (max = 0.15556)
# Accuracy was none
#
# [Epoch 19/50]
# Train loss =     0.18932 (min =     0.19774)    accuracy = 0.91111 (max = 0.91111)
# Test  loss =     2.29275 (min =     0.72341)    accuracy = 0.11111 (max = 0.20000)
#
# Accuracy was none
# [Epoch 20/50] Train loss =     0.18711 (min =     0.18932)    accuracy = 0.93333 (max = 0.91111) | Test  loss =     1.37106 (min =     0.72341)    accuracy = 0.17778 (max = 0.20000)
# Accuracy was none
# [Epoch 21/50] Train loss =     0.18046 (min =     0.18711)    accuracy = 0.93333 (max = 0.93333) | Test  loss =     2.31652 (min =     0.72341)    accuracy = 0.17778 (max = 0.20000)
# Accuracy was none
# [Epoch 22/50] Train loss =     0.17525 (min =     0.18046)    accuracy = 0.97778 (max = 0.93333) | Test  loss =     2.11738 (min =     0.72341)    accuracy = 0.15556 (max = 0.20000)
# Accuracy was none
# [Epoch 23/50] Train loss =     0.16856 (min =     0.17525)    accuracy = 0.93333 (max = 0.97778) | Test  loss =     1.36177 (min =     0.72341)    accuracy = 0.15556 (max = 0.20000)
# Accuracy was none
# [Epoch 24/50] Train loss =     0.15486 (min =     0.16856)    accuracy = 0.95556 (max = 0.97778) | Test  loss =     2.64615 (min =     0.72341)    accuracy = 0.13333 (max = 0.20000)
# Accuracy was none
# [Epoch 25/50] Train loss =     0.14394 (min =     0.15486)    accuracy = 0.95556 (max = 0.97778) | Test  loss =     1.73137 (min =     0.72341)    accuracy = 0.17778 (max = 0.20000)
# Accuracy was none
# [Epoch 26/50] Train loss =     0.13994 (min =     0.14394)    accuracy = 0.97778 (max = 0.97778) | Test  loss =     1.35521 (min =     0.72341)    accuracy = 0.15556 (max = 0.20000)
# Accuracy was none
# [Epoch 27/50] Train loss =     0.13678 (min =     0.13994)    accuracy = 0.97778 (max = 0.97778) | Test  loss =     2.22224 (min =     0.72341)    accuracy = 0.15556 (max = 0.20000)
# Accuracy was none
# [Epoch 28/50] Train loss =     0.13573 (min =     0.13678)    accuracy = 0.97778 (max = 0.97778) | Test  loss =     1.69684 (min =     0.72341)    accuracy = 0.11111 (max = 0.20000)
# Accuracy was none
# [Epoch 29/50] Train loss =     0.12638 (min =     0.13573)    accuracy = 0.97778 (max = 0.97778) | Test  loss =     1.81632 (min =     0.72341)    accuracy = 0.24444 (max = 0.20000)
# Accuracy was none
# [Epoch 30/50] Train loss =     0.10741 (min =     0.12638)    accuracy = 0.97778 (max = 0.97778) | Test  loss =     1.68054 (min =     0.72341)    accuracy = 0.17778 (max = 0.24444)
# Accuracy was none
# [Epoch 31/50] Train loss =     0.08906 (min =     0.10741)    accuracy = 0.97778 (max = 0.97778) | Test  loss =     2.13012 (min =     0.72341)    accuracy = 0.22222 (max = 0.24444)
# Accuracy was none
# [Epoch 32/50] Train loss =     0.08403 (min =     0.08906)    accuracy = 0.97778 (max = 0.97778) | Test  loss =     1.87878 (min =     0.72341)    accuracy = 0.26667 (max = 0.24444)
# Accuracy was none
# [Epoch 33/50] Train loss =     0.09207 (min =     0.08403)    accuracy = 0.97778 (max = 0.97778) | Test  loss =     1.79496 (min =     0.72341)    accuracy = 0.22222 (max = 0.26667)
# Accuracy was none
# [Epoch 34/50] Train loss =     0.07806 (min =     0.08403)    accuracy = 0.97778 (max = 0.97778) | Test  loss =     2.17384 (min =     0.72341)    accuracy = 0.28889 (max = 0.26667)
# Accuracy was none
# [Epoch 35/50] Train loss =     0.07495 (min =     0.07806)    accuracy = 1.00000 (max = 0.97778) | Test  loss =     1.90545 (min =     0.72341)    accuracy = 0.22222 (max = 0.28889)
# Accuracy was none
# [Epoch 36/50] Train loss =     0.07268 (min =     0.07495)    accuracy = 0.97778 (max = 1.00000) | Test  loss =     1.79937 (min =     0.72341)    accuracy = 0.20000 (max = 0.28889)
# Accuracy was none
# [Epoch 37/50] Train loss =     0.06858 (min =     0.07268)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.89792 (min =     0.72341)    accuracy = 0.20000 (max = 0.28889)
# Accuracy was none
# [Epoch 38/50] Train loss =     0.07369 (min =     0.06858)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.77029 (min =     0.72341)    accuracy = 0.20000 (max = 0.28889)
# Accuracy was none
#
# [Epoch 39/50]
# Train loss =     0.06230 (min =     0.06858)    accuracy = 1.00000 (max = 1.00000)
# Test  loss =     2.15925 (min =     0.72341)    accuracy = 0.22222 (max = 0.28889)
#
# Accuracy was none
# [Epoch 40/50] Train loss =     0.06040 (min =     0.06230)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     1.76200 (min =     0.72341)    accuracy = 0.17778 (max = 0.28889)
# Accuracy was none
# [Epoch 41/50] Train loss =     0.06048 (min =     0.06040)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.27994 (min =     0.72341)    accuracy = 0.20000 (max = 0.28889)
# Accuracy was none
# [Epoch 42/50] Train loss =     0.06821 (min =     0.06040)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.80623 (min =     0.72341)    accuracy = 0.20000 (max = 0.28889)
# Accuracy was none
# [Epoch 43/50] Train loss =     0.07239 (min =     0.06040)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     1.56157 (min =     0.72341)    accuracy = 0.28889 (max = 0.28889)
# Accuracy was none
# [Epoch 44/50] Train loss =     0.07717 (min =     0.06040)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.17137 (min =     0.72341)    accuracy = 0.24444 (max = 0.28889)
# Accuracy was none
# [Epoch 45/50] Train loss =     0.06245 (min =     0.06040)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.70034 (min =     0.72341)    accuracy = 0.24444 (max = 0.28889)
# Accuracy was none
# [Epoch 46/50] Train loss =     0.06018 (min =     0.06040)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.37808 (min =     0.72341)    accuracy = 0.26667 (max = 0.28889)
# Accuracy was none
# [Epoch 47/50] Train loss =     0.06344 (min =     0.06018)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     1.72010 (min =     0.72341)    accuracy = 0.24444 (max = 0.28889)
# Accuracy was none
# [Epoch 48/50] Train loss =     0.06537 (min =     0.06018)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.35066 (min =     0.72341)    accuracy = 0.24444 (max = 0.28889)
# Accuracy was none
# [Epoch 49/50] Train loss =     0.05629 (min =     0.06018)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.02052 (min =     0.72341)    accuracy = 0.22222 (max = 0.28889)
# Accuracy was none

# %%
# import the best network during training 
net.load_state_dict(torch.load(trained_folder + '/network.pt'))
net.export_hdf5(trained_folder + '/network.net')

# Get the output for the input to each place
test_loader2  = DataLoader(dataset=testing_set , batch_size=batch_size, shuffle=False)
rate = []
labels = []
for i, (input, label) in enumerate(test_loader2):
    output = net(input.to(device)) # Get network output
    #guesses = assistant.classifier(output).cpu().data.numpy() # get the predictions 
    rate.extend(Rate.rate(output).cpu().data.numpy()) # Get the firing rates for each place 
    labels.extend(label.cpu().data.numpy()) # Get place labels


# # Get rates in percentages of total
# for i in range(num_places):
#     sum = np.sum(rate[i])
#     if sum != 0:
#         rate[i] = np.divide(rate[i],sum)

# Make confusion matrix annotations
accuracy = 0
matches = []
annotations = [['' for i in range(num_places)] for j in range(num_places)]
for qryIndex in range(num_places):
    max_idx = np.argmax(rate[qryIndex])
    matches.append(max_idx)
    annotations[max_idx][qryIndex] = 'x'
    if max_idx ==qryIndex:
        accuracy += 1


#--------------- Apply a sequencer ------------------#
I = np.identity(sequence_length)
conv = signal.convolve2d(rate, I, mode='same')
print(np.shape(conv))

# Make confusion matrix annotations
accuracy_s = 0
matches_with_seq = []
annotations_s = [['' for i in range(num_places)] for j in range(num_places)]
for qryIndex in range(num_places):
    max_idx = np.argmax(conv[qryIndex])
    matches_with_seq.append(max_idx)
    annotations_s[max_idx][qryIndex] = 'x'
    if max_idx == qryIndex:
        accuracy_s += 1
# Out:
# (45, 45)

# %%
#--------------- Save Results ------------------#

# Make new folder for results
from tracemalloc import start
from plotting import plot_gps


time_stamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
results_path = "./../results/" + time_stamp
os.mkdir(results_path)


# Save query and match images 
images_path = results_path + "/matched_images"
images_path_seq = results_path + "/matched_images_seq"
os.mkdir(images_path)
os.mkdir(images_path_seq)

print('help')
plot_match_images(images_path + "/", matches, training_set.place_images, testing_set.place_images)
plot_match_images(images_path_seq + "/", matches_with_seq, training_set.place_images, testing_set.place_images)

# Save the confusion matrices
confusion_path = results_path + "/confusion_matrices"
os.mkdir(confusion_path)
rate = transpose(rate)
conv = transpose(conv)
output_path = confusion_path + "/confusion_matrix" 
output_path_s = confusion_path + "/confusion_matrix_seq" 
plot_confusion_matrix(rate, labels, annotations, output_path, vmin, vmax)
plot_confusion_matrix(conv, labels, annotations_s, output_path_s, vmin, vmax)

# Save GPS map'
gps_path = results_path + "/gps_locations"
plot_gps(gps_path, training_set.place_locations, testing_set.place_locations)

# Save test settings and accuracy
accuracy = accuracy/num_places
accuracy_s = accuracy_s/num_places
# Out:
# help

# %%
log_path = results_path + "/log.txt"
log_string  = """
---- DATA SETTINGS ---- 
Training datasets = {}
Testing datasets = {} 
# Places = {}
Start dist = {} [m]
Place gap = {} [m]
Place duration = {} [s]
Samples per second = {} 
Max spikes per sample = {}
---- NETWORK SETTINGS ---- 
Input size = {}x{} 
Threshold = {}
---- TRAINING SETTINGS ---- 
Epochs = {}
Batch size = {}
---- SEQUENCER SETTINGS ----
Sequence lengtth = {} 
---- RESULTS ----
Accuracy = {}
Accuracy (sequencer) = {}
""".format(train_name,test_name,num_places,start_dist,place_gap,place_duration,
                samples_per_sec,max_spikes,input_size,input_size,threshold,epochs,
                batch_size,sequence_length,accuracy,accuracy_s)
f = open(log_path,'w')
f.write(log_string)
f.close()

print("The accuracy of the network is: " + str(accuracy))
print("The accuracy with a sequencer is: " + str(accuracy_s))
# Out:
# The accuracy of the network is: 0.2222222222222222
# The accuracy with a sequencer is: 0.5111111111111111
