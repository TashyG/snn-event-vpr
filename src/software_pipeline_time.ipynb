# %% [markdown]
# %%% Imports

# %%
from __future__ import annotations
from time import time
from BrisbaneVPRDatasetTime import BrisbaneVPRDatasetTime
from VPRNetwork import VPRNetwork
from plotting import plot_confusion_matrix, plot_match_images, plot_gps
from constants import brisbane_event_traverses, brisbane_event_traverses_aliases
from utils import get_short_traverse_name

import os, sys
import torch
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from matplotlib import animation
from scipy import signal
from datetime import datetime

import numpy as np

import lava.lib.dl.slayer as slayer
from lava.lib.dl.slayer.classifier import Rate

# %%
# Training settings
from cgi import test


epochs = 50
batch_size = 10

# Network settings
input_size = 34
threshold = 1.0

# Data settings
train_traverse = brisbane_event_traverses[0]
test_traverse = brisbane_event_traverses[2]
train_name = brisbane_event_traverses_aliases[get_short_traverse_name(train_traverse)]
test_name = brisbane_event_traverses_aliases[get_short_traverse_name(test_traverse)]
num_places = 45
start_dist = 200
place_gap = 100 #164/num_places # The streams run for approximately 164 seconds 
samples_per_sec = 1000
place_duration = 2
max_spikes = None

# Sequencer settings
sequence_length = 3

# Plot settings
redo_plot = False
vmin = 0
vmax = 0.05

def transpose( matrix):
    if len(matrix) == 0:
        return []
    return [[matrix[i][j] for i in range(len(matrix))] for j in range(len(matrix[0]))]


# Make a folder for the trained network
trained_folder = 'Trained'
os.makedirs(trained_folder, exist_ok=True)

# Use GPU
print(torch.cuda.is_available())
device = torch.device('cuda')

#---------------- Create the Network -----------------#

# Create the network
net = VPRNetwork(input_size, num_places, threshold=threshold).to(device)
# Out:
# True

# %%
# Load the data
training_set = BrisbaneVPRDatasetTime(train_traverse, train=True, place_duration = place_duration, place_gap=place_gap, num_places=num_places, start_dist=start_dist,samples_per_sec=samples_per_sec, max_spikes=max_spikes)
testing_set  = BrisbaneVPRDatasetTime(test_traverse, train=False, place_duration = place_duration, training_locations=training_set.place_locations, place_gap=place_gap, num_places=num_places, start_dist=start_dist, samples_per_sec=samples_per_sec, max_spikes=max_spikes)
            
train_loader = DataLoader(dataset=training_set, batch_size=batch_size, shuffle=True)
test_loader  = DataLoader(dataset=testing_set , batch_size=batch_size, shuffle=True)
# Out:
# Loading training event streams ...
# Adding GPS
# Duration: 527.16s (which is 3432338 events)
# Distance: 6308.49m (which is 3432338 events)
# /home/n10223622/snn-event-vpr/src/BrisbaneVPRDatasetTime.py:206: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chopped_stream['t'] -= chop_start
# Place: 0
# Distance: 27.09m (which is 16831 events)
# Place: 1
# Distance: 22.37m (which is 11571 events)
# Place: 2
# Distance: 24.62m (which is 6218 events)
# Place: 3
# Distance: 25.05m (which is 11757 events)
# Place: 4
# Distance: 25.69m (which is 16353 events)
# Place: 5
# Distance: 26.19m (which is 10336 events)
# Place: 6
# Distance: 25.29m (which is 9351 events)
# Place: 7
# Distance: 14.78m (which is 13630 events)
# Place: 8
# Distance: 25.71m (which is 19693 events)
# Place: 9
# Distance: 26.06m (which is 19902 events)
# Place: 10
# Distance: 29.38m (which is 20254 events)
# Place: 11
# Distance: 30.70m (which is 19454 events)
# Place: 12
# Distance: 30.11m (which is 25099 events)
# Place: 13
# Distance: 30.32m (which is 31980 events)
# Place: 14
# Distance: 30.67m (which is 31916 events)
# Place: 15
# Distance: 30.15m (which is 20344 events)
# Place: 16
# Distance: 26.11m (which is 13738 events)
# Place: 17
# Distance: 26.72m (which is 5523 events)
# Place: 18
# Distance: 35.03m (which is 8125 events)
# Place: 19
# Distance: 34.11m (which is 6218 events)
# Place: 20
# Distance: 34.72m (which is 2781 events)
# Place: 21
# Distance: 34.94m (which is 2556 events)
# Place: 22
# Distance: 31.86m (which is 2479 events)
# Place: 23
# Distance: 27.06m (which is 5047 events)
# Place: 24
# Distance: 24.74m (which is 1313 events)
# Place: 25
# Distance: 31.07m (which is 7835 events)
# Place: 26
# Distance: 28.69m (which is 16315 events)
# Place: 27
# Distance: 28.37m (which is 8889 events)
# Place: 28
# Distance: 30.50m (which is 15303 events)
# Place: 29
# Distance: 29.82m (which is 19846 events)
# Place: 30
# Distance: 32.17m (which is 16925 events)
# Place: 31
# Distance: 31.32m (which is 29244 events)
# Place: 32
# Distance: 30.02m (which is 18011 events)
# Place: 33
# Distance: 23.15m (which is 11257 events)
# Place: 34
# Distance: 9.41m (which is 8450 events)
# Place: 35
# Distance: 19.72m (which is 7151 events)
# Place: 36
# Distance: 6.57m (which is 5243 events)
# Place: 37
# Distance: 27.30m (which is 7425 events)
# Place: 38
# Distance: 28.22m (which is 15030 events)
# Place: 39
# Distance: 29.24m (which is 11479 events)
# Place: 40
# Distance: 30.27m (which is 26435 events)
# Place: 41
# Distance: 30.40m (which is 23262 events)
# Place: 42
# Distance: 29.91m (which is 26455 events)
# Place: 43
# Distance: 29.23m (which is 12309 events)
# Place: 44
# Distance: 28.12m (which is 27836 events)
# The number of training substreams is: 45
# Loading testing event streams ...
# Adding GPS
# Duration: 516.16s (which is 3442353 events)
# Distance: 6023.50m (which is 3442353 events)
# 14.0
# Place: 0
# Distance: 29.49m (which is 20846 events)
# 21.0
# Place: 1
# Distance: 22.28m (which is 14344 events)
# 34.46
# Place: 2
# Distance: 23.83m (which is 6259 events)
# 42.27
# Place: 3
# Distance: 26.10m (which is 16077 events)
# 50.09
# Place: 4
# Distance: 27.89m (which is 15579 events)
# 56.97
# Place: 5
# Distance: 29.73m (which is 14459 events)
# 63.73
# Place: 6
# Distance: 27.65m (which is 18601 events)
# 72.77
# Place: 7
# Distance: 14.84m (which is 18188 events)
# 82.83
# Place: 8
# Distance: 27.50m (which is 21237 events)
# 89.87
# Place: 9
# Distance: 29.98m (which is 23725 events)
# 96.33
# Place: 10
# Distance: 32.40m (which is 26080 events)
# 102.56
# Place: 11
# Distance: 31.56m (which is 23729 events)
# 108.84
# Place: 12
# Distance: 30.88m (which is 26314 events)
# 115.63
# Place: 13
# Distance: 29.45m (which is 26300 events)
# 122.16
# Place: 14
# Distance: 31.69m (which is 32463 events)
# 128.57
# Place: 15
# Distance: 30.38m (which is 19451 events)
# 135.08
# Place: 16
# Distance: 28.04m (which is 19098 events)
# 160.72
# Place: 17
# Distance: 27.32m (which is 2197 events)
# 167.34
# /home/n10223622/snn-event-vpr/src/BrisbaneVPRDatasetTime.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chopped_stream['t'] -= chop_start
# Place: 18
# Distance: 34.35m (which is 10415 events)
# 173.14
# Place: 19
# Distance: 33.06m (which is 7652 events)
# 179.26
# Place: 20
# Distance: 31.54m (which is 4713 events)
# 185.49
# Place: 21
# Distance: 32.30m (which is 4041 events)
# 191.69
# Place: 22
# Distance: 32.49m (which is 3602 events)
# 197.74
# Place: 23
# Distance: 33.54m (which is 10000 events)
# 203.84
# Place: 24
# Distance: 33.09m (which is 4892 events)
# 209.87
# Place: 25
# Distance: 31.64m (which is 9742 events)
# 216.78
# Place: 26
# Distance: 29.66m (which is 23734 events)
# 223.54
# Place: 27
# Distance: 29.10m (which is 15803 events)
# 230.3
# Place: 28
# Distance: 29.89m (which is 22525 events)
# 236.92
# Place: 29
# Distance: 30.56m (which is 20964 events)
# 243.26
# Place: 30
# Distance: 29.51m (which is 24010 events)
# 266.79
# Place: 31
# Distance: 14.08m (which is 2331 events)
# 281.78
# Place: 32
# Distance: 9.05m (which is 18964 events)
# 297.49
# Place: 33
# Distance: 15.90m (which is 14506 events)
# 310.43
# Place: 34
# Distance: 17.03m (which is 16839 events)
# 322.54
# Place: 35
# Distance: 12.76m (which is 5166 events)
# 363.73
# Place: 36
# Distance: 18.61m (which is 8111 events)
# 372.97
# Place: 37
# Distance: 26.55m (which is 2714 events)
# 380.23
# Place: 38
# Distance: 28.57m (which is 28658 events)
# 387.14
# Place: 39
# Distance: 29.72m (which is 4182 events)
# 393.77
# Place: 40
# Distance: 31.24m (which is 38866 events)
# 400.27
# Place: 41
# Distance: 30.29m (which is 6705 events)
# 406.91
# Place: 42
# Distance: 29.76m (which is 34413 events)
# 413.89
# Place: 43
# Distance: 28.89m (which is 2594 events)
# 420.95
# Place: 44
# Distance: 28.15m (which is 32705 events)
# The number of testing substreams is: 45

# %%
# Define an optimiser 
optimizer = torch.optim.Adam(net.parameters(), lr=0.001)

# Training the network
error = slayer.loss.SpikeRate(true_rate=0.2, false_rate=0.03, reduction='sum').to(device)

# Create a training assistant object
stats = slayer.utils.LearningStats()
assistant = slayer.utils.Assistant(net, error, optimizer, stats, classifier=slayer.classifier.Rate.predict)


if redo_plot:
    for i, (input, label) in enumerate(train_loader): # training loop
        output = assistant.train(input, label)

else: 
    for epoch in range(epochs):

        for i, (input, label) in enumerate(train_loader): # training loop
            output = assistant.train(input, label)
        print(f'\r[Epoch {epoch:2d}/{epochs}] {stats}', end='')

        for i, (input, label) in enumerate(test_loader): # training loop
            output = assistant.test(input, label)
        print(f'\r[Epoch {epoch:2d}/{epochs}] {stats}', end='')

        if epoch%20 == 19: # cleanup display
            print('\r', ' '*len(f'\r[Epoch {epoch:2d}/{epochs}] {stats}'))
            stats_str = str(stats).replace("| ", "\n")
            print(f'[Epoch {epoch:2d}/{epochs}]\n{stats_str}')

        if stats.testing.best_accuracy:
            torch.save(net.state_dict(), trained_folder + '/network.pt')
        stats.update()
        stats.save(trained_folder + '/')
        net.grad_flow(trained_folder + '/')
# Out:
# [Epoch  0/50] Train loss =     1.14872 | Test  loss =     0.71715
# Accuracy was none
#
# Accuracy was none
#
# Accuracy was none
# [Epoch  1/50] Train loss =     0.67546 (min =     1.14872)    accuracy = 0.02222  | Test  loss =     0.81238 (min =     0.71715)    accuracy = 0.06667
# Accuracy was none
# [Epoch  2/50] Train loss =     0.59704 (min =     0.67546)    accuracy = 0.08889 (max = 0.02222) | Test  loss =     1.24785 (min =     0.71715)    accuracy = 0.04444 (max = 0.06667)
# Accuracy was none
# [Epoch  3/50] Train loss =     0.57217 (min =     0.59704)    accuracy = 0.20000 (max = 0.08889) | Test  loss =     1.39044 (min =     0.71715)    accuracy = 0.06667 (max = 0.06667)
# Accuracy was none
# [Epoch  4/50] Train loss =     0.46374 (min =     0.57217)    accuracy = 0.35556 (max = 0.20000) | Test  loss =     1.11316 (min =     0.71715)    accuracy = 0.11111 (max = 0.06667)
# Accuracy was none
# [Epoch  5/50] Train loss =     0.43932 (min =     0.46374)    accuracy = 0.40000 (max = 0.35556) | Test  loss =     1.44308 (min =     0.71715)    accuracy = 0.08889 (max = 0.11111)
# Accuracy was none
# [Epoch  6/50] Train loss =     0.38177 (min =     0.43932)    accuracy = 0.40000 (max = 0.40000) | Test  loss =     2.25369 (min =     0.71715)    accuracy = 0.11111 (max = 0.11111)
# Accuracy was none
# [Epoch  7/50] Train loss =     0.38182 (min =     0.38177)    accuracy = 0.51111 (max = 0.40000) | Test  loss =     1.74117 (min =     0.71715)    accuracy = 0.06667 (max = 0.11111)
# Accuracy was none
# [Epoch  8/50] Train loss =     0.34221 (min =     0.38177)    accuracy = 0.55556 (max = 0.51111) | Test  loss =     2.26979 (min =     0.71715)    accuracy = 0.20000 (max = 0.11111)
# Accuracy was none
# [Epoch  9/50] Train loss =     0.31327 (min =     0.34221)    accuracy = 0.77778 (max = 0.55556) | Test  loss =     1.47904 (min =     0.71715)    accuracy = 0.06667 (max = 0.20000)
# Accuracy was none
# [Epoch 10/50] Train loss =     0.32332 (min =     0.31327)    accuracy = 0.77778 (max = 0.77778) | Test  loss =     2.21402 (min =     0.71715)    accuracy = 0.11111 (max = 0.20000)
# Accuracy was none
# [Epoch 11/50] Train loss =     0.27561 (min =     0.31327)    accuracy = 0.75556 (max = 0.77778) | Test  loss =     2.06915 (min =     0.71715)    accuracy = 0.17778 (max = 0.20000)
# Accuracy was none
# [Epoch 12/50] Train loss =     0.27777 (min =     0.27561)    accuracy = 0.77778 (max = 0.77778) | Test  loss =     1.41738 (min =     0.71715)    accuracy = 0.08889 (max = 0.20000)
# Accuracy was none
# [Epoch 13/50] Train loss =     0.24466 (min =     0.27561)    accuracy = 0.88889 (max = 0.77778) | Test  loss =     2.33616 (min =     0.71715)    accuracy = 0.20000 (max = 0.20000)
# Accuracy was none
# [Epoch 14/50] Train loss =     0.23217 (min =     0.24466)    accuracy = 0.88889 (max = 0.88889) | Test  loss =     1.52741 (min =     0.71715)    accuracy = 0.15556 (max = 0.20000)
# Accuracy was none
# [Epoch 15/50] Train loss =     0.22450 (min =     0.23217)    accuracy = 0.93333 (max = 0.88889) | Test  loss =     3.09019 (min =     0.71715)    accuracy = 0.17778 (max = 0.20000)
# Accuracy was none
# [Epoch 16/50] Train loss =     0.20299 (min =     0.22450)    accuracy = 0.95556 (max = 0.93333) | Test  loss =     1.69968 (min =     0.71715)    accuracy = 0.20000 (max = 0.20000)
# Accuracy was none
# [Epoch 17/50] Train loss =     0.20100 (min =     0.20299)    accuracy = 0.95556 (max = 0.95556) | Test  loss =     1.93039 (min =     0.71715)    accuracy = 0.13333 (max = 0.20000)
# Accuracy was none
# [Epoch 18/50] Train loss =     0.16804 (min =     0.20100)    accuracy = 0.95556 (max = 0.95556) | Test  loss =     1.91523 (min =     0.71715)    accuracy = 0.28889 (max = 0.20000)
# Accuracy was none
#
# [Epoch 19/50]
# Train loss =     0.15610 (min =     0.16804)    accuracy = 0.93333 (max = 0.95556)
# Test  loss =     2.23324 (min =     0.71715)    accuracy = 0.17778 (max = 0.28889)
#
# Accuracy was none
# [Epoch 20/50] Train loss =     0.14945 (min =     0.15610)    accuracy = 0.95556 (max = 0.95556) | Test  loss =     2.07763 (min =     0.71715)    accuracy = 0.15556 (max = 0.28889)
# Accuracy was none
# [Epoch 21/50] Train loss =     0.14200 (min =     0.14945)    accuracy = 0.97778 (max = 0.95556) | Test  loss =     1.68763 (min =     0.71715)    accuracy = 0.22222 (max = 0.28889)
# Accuracy was none
# [Epoch 22/50] Train loss =     0.13595 (min =     0.14200)    accuracy = 0.97778 (max = 0.97778) | Test  loss =     2.80135 (min =     0.71715)    accuracy = 0.20000 (max = 0.28889)
# Accuracy was none
# [Epoch 23/50] Train loss =     0.12903 (min =     0.13595)    accuracy = 0.97778 (max = 0.97778) | Test  loss =     1.98011 (min =     0.71715)    accuracy = 0.22222 (max = 0.28889)
# Accuracy was none
# [Epoch 24/50] Train loss =     0.13275 (min =     0.12903)    accuracy = 0.95556 (max = 0.97778) | Test  loss =     2.51534 (min =     0.71715)    accuracy = 0.20000 (max = 0.28889)
# Accuracy was none
# [Epoch 25/50] Train loss =     0.12463 (min =     0.12903)    accuracy = 1.00000 (max = 0.97778) | Test  loss =     3.03584 (min =     0.71715)    accuracy = 0.22222 (max = 0.28889)
# Accuracy was none
# [Epoch 26/50] Train loss =     0.10957 (min =     0.12463)    accuracy = 0.97778 (max = 1.00000) | Test  loss =     2.47167 (min =     0.71715)    accuracy = 0.22222 (max = 0.28889)
# Accuracy was none
# [Epoch 27/50] Train loss =     0.10059 (min =     0.10957)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.56899 (min =     0.71715)    accuracy = 0.24444 (max = 0.28889)
# Accuracy was none
# [Epoch 28/50] Train loss =     0.09792 (min =     0.10059)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.59906 (min =     0.71715)    accuracy = 0.26667 (max = 0.28889)
# Accuracy was none
# [Epoch 29/50] Train loss =     0.08661 (min =     0.09792)    accuracy = 0.97778 (max = 1.00000) | Test  loss =     2.31199 (min =     0.71715)    accuracy = 0.24444 (max = 0.28889)
# Accuracy was none
# [Epoch 30/50] Train loss =     0.08332 (min =     0.08661)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.18595 (min =     0.71715)    accuracy = 0.26667 (max = 0.28889)
# Accuracy was none
# [Epoch 31/50] Train loss =     0.07875 (min =     0.08332)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.52827 (min =     0.71715)    accuracy = 0.20000 (max = 0.28889)
# Accuracy was none
# [Epoch 32/50] Train loss =     0.07404 (min =     0.07875)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     3.00566 (min =     0.71715)    accuracy = 0.26667 (max = 0.28889)
# Accuracy was none
# [Epoch 33/50] Train loss =     0.07326 (min =     0.07404)    accuracy = 0.97778 (max = 1.00000) | Test  loss =     2.66807 (min =     0.71715)    accuracy = 0.26667 (max = 0.28889)
# Accuracy was none
# [Epoch 34/50] Train loss =     0.07196 (min =     0.07326)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.44006 (min =     0.71715)    accuracy = 0.28889 (max = 0.28889)
# Accuracy was none
# [Epoch 35/50] Train loss =     0.06663 (min =     0.07196)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.81300 (min =     0.71715)    accuracy = 0.26667 (max = 0.28889)
# Accuracy was none
# [Epoch 36/50] Train loss =     0.06021 (min =     0.06663)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.13153 (min =     0.71715)    accuracy = 0.22222 (max = 0.28889)
# Accuracy was none
# [Epoch 37/50] Train loss =     0.05992 (min =     0.06021)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.66535 (min =     0.71715)    accuracy = 0.22222 (max = 0.28889)
# Accuracy was none
# [Epoch 38/50] Train loss =     0.06629 (min =     0.05992)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.35602 (min =     0.71715)    accuracy = 0.24444 (max = 0.28889)
# Accuracy was none
#
# [Epoch 39/50]
# Train loss =     0.05615 (min =     0.05992)    accuracy = 1.00000 (max = 1.00000)
# Test  loss =     1.76481 (min =     0.71715)    accuracy = 0.24444 (max = 0.28889)
#
# Accuracy was none
# [Epoch 40/50] Train loss =     0.05987 (min =     0.05615)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     3.64699 (min =     0.71715)    accuracy = 0.24444 (max = 0.28889)
# Accuracy was none
# [Epoch 41/50] Train loss =     0.07049 (min =     0.05615)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.13516 (min =     0.71715)    accuracy = 0.22222 (max = 0.28889)
# Accuracy was none
# [Epoch 42/50] Train loss =     0.08287 (min =     0.05615)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     1.60063 (min =     0.71715)    accuracy = 0.28889 (max = 0.28889)
# Accuracy was none
# [Epoch 43/50] Train loss =     0.07561 (min =     0.05615)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     3.32262 (min =     0.71715)    accuracy = 0.28889 (max = 0.28889)
# Accuracy was none
# [Epoch 44/50] Train loss =     0.07346 (min =     0.05615)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.58801 (min =     0.71715)    accuracy = 0.17778 (max = 0.28889)
# Accuracy was none
# [Epoch 45/50] Train loss =     0.06212 (min =     0.05615)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.11426 (min =     0.71715)    accuracy = 0.26667 (max = 0.28889)
# Accuracy was none
# [Epoch 46/50] Train loss =     0.06128 (min =     0.05615)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.09415 (min =     0.71715)    accuracy = 0.26667 (max = 0.28889)
# Accuracy was none
# [Epoch 47/50] Train loss =     0.06152 (min =     0.05615)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     3.42109 (min =     0.71715)    accuracy = 0.26667 (max = 0.28889)
# Accuracy was none
# [Epoch 48/50] Train loss =     0.06968 (min =     0.05615)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.12763 (min =     0.71715)    accuracy = 0.24444 (max = 0.28889)
# Accuracy was none
# [Epoch 49/50] Train loss =     0.05692 (min =     0.05615)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     2.32146 (min =     0.71715)    accuracy = 0.28889 (max = 0.28889)
# Accuracy was none

# %%
# import the best network during training 
net.load_state_dict(torch.load(trained_folder + '/network.pt'))
net.export_hdf5(trained_folder + '/network.net')

# Get the output for the input to each place
test_loader2  = DataLoader(dataset=testing_set , batch_size=batch_size, shuffle=False)
rate = []
labels = []
for i, (input, label) in enumerate(test_loader2):
    output = net(input.to(device)) # Get network output
    #guesses = assistant.classifier(output).cpu().data.numpy() # get the predictions 
    rate.extend(Rate.rate(output).cpu().data.numpy()) # Get the firing rates for each place 
    labels.extend(label.cpu().data.numpy()) # Get place labels


# # Get rates in percentages of total
# for i in range(num_places):
#     sum = np.sum(rate[i])
#     if sum != 0:
#         rate[i] = np.divide(rate[i],sum)

# Make confusion matrix annotations
accuracy = 0
matches = []
annotations = [['' for i in range(num_places)] for j in range(num_places)]
for qryIndex in range(num_places):
    max_idx = np.argmax(rate[qryIndex])
    matches.append(max_idx)
    annotations[max_idx][qryIndex] = 'x'
    if max_idx ==qryIndex:
        accuracy += 1


#--------------- Apply a sequencer ------------------#
I = np.identity(sequence_length)
conv = signal.convolve2d(rate, I, mode='same')
print(np.shape(conv))

# Make confusion matrix annotations
accuracy_s = 0
matches_with_seq = []
annotations_s = [['' for i in range(num_places)] for j in range(num_places)]
for qryIndex in range(num_places):
    max_idx = np.argmax(conv[qryIndex])
    matches_with_seq.append(max_idx)
    annotations_s[max_idx][qryIndex] = 'x'
    if max_idx == qryIndex:
        accuracy_s += 1
# Out:
# (45, 45)

# %%
#--------------- Save Results ------------------#

# Make new folder for results
from tracemalloc import start
from plotting import plot_gps


time_stamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
results_path = "./../results/" + time_stamp
os.mkdir(results_path)


# Save query and match images 
images_path = results_path + "/matched_images"
images_path_seq = results_path + "/matched_images_seq"
os.mkdir(images_path)
os.mkdir(images_path_seq)

print('help')
plot_match_images(images_path + "/", matches, training_set.place_images, testing_set.place_images)
plot_match_images(images_path_seq + "/", matches_with_seq, training_set.place_images, testing_set.place_images)

# Save the confusion matrices
confusion_path = results_path + "/confusion_matrices"
os.mkdir(confusion_path)
rate = transpose(rate)
conv = transpose(conv)
output_path = confusion_path + "/confusion_matrix" 
output_path_s = confusion_path + "/confusion_matrix_seq" 
plot_confusion_matrix(rate, labels, annotations, output_path, vmin, vmax)
plot_confusion_matrix(conv, labels, annotations_s, output_path_s, vmin, vmax)

# Save GPS map'
gps_path = results_path + "/gps_locations"
plot_gps(gps_path, training_set.place_locations, testing_set.place_locations)

# Save test settings and accuracy
accuracy = accuracy/num_places
accuracy_s = accuracy_s/num_places
# Out:
# help

# %%
log_path = results_path + "/log.txt"
log_string  = """
---- DATA SETTINGS ---- 
Training datasets = {}
Testing datasets = {} 
# Places = {}
Start dist = {} [m]
Place gap = {} [m]
Place duration = {} [s]
Samples per second = {} 
Max spikes per sample = {}
---- NETWORK SETTINGS ---- 
Input size = {}x{} 
Threshold = {}
---- TRAINING SETTINGS ---- 
Epochs = {}
Batch size = {}
---- SEQUENCER SETTINGS ----
Sequence lengtth = {} 
---- RESULTS ----
Accuracy = {}
Accuracy (sequencer) = {}
""".format(train_name,test_name,num_places,start_dist,place_gap,place_duration,
                samples_per_sec,max_spikes,input_size,input_size,threshold,epochs,
                batch_size,sequence_length,accuracy,accuracy_s)
f = open(log_path,'w')
f.write(log_string)
f.close()

print("The accuracy of the network is: " + str(accuracy))
print("The accuracy with a sequencer is: " + str(accuracy_s))
# Out:
# The accuracy of the network is: 0.17777777777777778
# The accuracy with a sequencer is: 0.4222222222222222
