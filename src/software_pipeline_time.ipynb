# %% [markdown]
# %%% Imports

# %%
from __future__ import annotations
from time import time
from BrisbaneVPRDatasetTime import BrisbaneVPRDatasetTime
from VPRNetwork import VPRNetwork
from plotting import plot_confusion_matrix, plot_match_images, plot_gps
from constants import brisbane_event_traverses, brisbane_event_traverses_aliases
from utils import get_short_traverse_name

import os, sys
import torch
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from matplotlib import animation
from scipy import signal
from datetime import datetime

import numpy as np

import lava.lib.dl.slayer as slayer
from lava.lib.dl.slayer.classifier import Rate

# %%
# Training settings
from cgi import test


epochs = 50
batch_size = 10

# Network settings
input_size = 34
threshold = 1.0

# Data settings
train_traverse = brisbane_event_traverses[0]
test_traverse = brisbane_event_traverses[1]
train_name = brisbane_event_traverses_aliases[get_short_traverse_name(train_traverse)]
test_name = brisbane_event_traverses_aliases[get_short_traverse_name(test_traverse)]
num_places = 45
start_dist = 200
place_gap = 100 #164/num_places # The streams run for approximately 164 seconds 
samples_per_sec = 1000
place_duration = 2
max_spikes = None

# Sequencer settings
sequence_length = 3

# Plot settings
redo_plot = False
vmin = 0
vmax = 0.05

def transpose( matrix):
    if len(matrix) == 0:
        return []
    return [[matrix[i][j] for i in range(len(matrix))] for j in range(len(matrix[0]))]


# Make a folder for the trained network
trained_folder = 'Trained'
os.makedirs(trained_folder, exist_ok=True)

# Use GPU
print(torch.cuda.is_available())
device = torch.device('cuda')

#---------------- Create the Network -----------------#

# Create the network
net = VPRNetwork(input_size, num_places, threshold=threshold).to(device)
# Out:
# True

# %%
# Load the data
training_set = BrisbaneVPRDatasetTime(train_traverse, train=True, place_duration = place_duration, place_gap=place_gap, num_places=num_places, start_dist=start_dist,samples_per_sec=samples_per_sec, max_spikes=max_spikes)
testing_set  = BrisbaneVPRDatasetTime(test_traverse, train=False, place_duration = place_duration, training_locations=training_set.place_locations, place_gap=place_gap, num_places=num_places, start_dist=start_dist, samples_per_sec=samples_per_sec, max_spikes=max_spikes)
            
train_loader = DataLoader(dataset=training_set, batch_size=batch_size, shuffle=True)
test_loader  = DataLoader(dataset=testing_set , batch_size=batch_size, shuffle=True)
# Out:
# Loading training event streams ...
# Adding GPS
# Duration: 527.16s (which is 3432338 events)
# Distance: 6308.49m (which is 3432338 events)
# /home/n10223622/snn-event-vpr/src/BrisbaneVPRDatasetTime.py:206: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chopped_stream['t'] -= chop_start
# Duration: 2.00s (which is 16831 events)
# Distance: 27.09m (which is 16831 events)
# 14.978595
# Duration: 2.00s (which is 11571 events)
# Distance: 22.37m (which is 11571 events)
# 22.462471
# Duration: 2.00s (which is 6218 events)
# Distance: 24.62m (which is 6218 events)
# 36.785084
# Duration: 2.00s (which is 11757 events)
# Distance: 25.05m (which is 11757 events)
# 44.84649
# Duration: 2.00s (which is 16353 events)
# Distance: 25.69m (which is 16353 events)
# 52.768036
# Duration: 2.00s (which is 10336 events)
# Distance: 26.19m (which is 10336 events)
# 60.328046
# Duration: 2.00s (which is 9351 events)
# Distance: 25.29m (which is 9351 events)
# 67.85967
# Duration: 2.00s (which is 13630 events)
# Distance: 14.78m (which is 13630 events)
# 76.874066
# Duration: 2.00s (which is 19693 events)
# Distance: 25.71m (which is 19693 events)
# 87.27611
# Duration: 2.00s (which is 19902 events)
# Distance: 26.06m (which is 19902 events)
# 94.883582
# Duration: 2.00s (which is 20254 events)
# Distance: 29.38m (which is 20254 events)
# 102.164128
# Duration: 2.00s (which is 19454 events)
# Distance: 30.70m (which is 19454 events)
# 108.867563
# Duration: 2.00s (which is 25099 events)
# Distance: 30.11m (which is 25099 events)
# 115.472282
# Duration: 2.00s (which is 31980 events)
# Distance: 30.32m (which is 31980 events)
# 122.292701
# Duration: 2.00s (which is 31916 events)
# Distance: 30.67m (which is 31916 events)
# 128.751136
# Duration: 2.00s (which is 20344 events)
# Distance: 30.15m (which is 20344 events)
# 135.342849
# Duration: 2.00s (which is 13738 events)
# Distance: 26.11m (which is 13738 events)
# 142.151486
# Duration: 2.00s (which is 5523 events)
# Distance: 26.72m (which is 5523 events)
# 151.63791
# Duration: 2.00s (which is 8125 events)
# Distance: 35.03m (which is 8125 events)
# 158.039293
# Duration: 2.00s (which is 6218 events)
# Distance: 34.11m (which is 6218 events)
# 163.765246
# Duration: 2.00s (which is 2781 events)
# Distance: 34.72m (which is 2781 events)
# 169.707574
# Duration: 2.00s (which is 2556 events)
# Distance: 34.94m (which is 2556 events)
# 175.457632
# Duration: 2.00s (which is 2479 events)
# Distance: 31.86m (which is 2479 events)
# 181.251142
# Duration: 2.00s (which is 5047 events)
# Distance: 27.06m (which is 5047 events)
# 187.91357
# Duration: 2.00s (which is 1313 events)
# Distance: 24.74m (which is 1313 events)
# 195.785776
# Duration: 2.00s (which is 7835 events)
# Distance: 31.07m (which is 7835 events)
# 202.698858
# Duration: 2.00s (which is 16315 events)
# Distance: 28.69m (which is 16315 events)
# 209.420258
# Duration: 2.00s (which is 8889 events)
# Distance: 28.37m (which is 8889 events)
# 216.428364
# Duration: 2.00s (which is 15303 events)
# Distance: 30.50m (which is 15303 events)
# 223.323846
# Duration: 2.00s (which is 19846 events)
# Distance: 29.82m (which is 19846 events)
# 229.880403
# Duration: 2.00s (which is 16925 events)
# Distance: 32.17m (which is 16925 events)
# 236.493639
# Duration: 2.00s (which is 29244 events)
# Distance: 31.32m (which is 29244 events)
# 242.778028
# Duration: 2.00s (which is 18011 events)
# Distance: 30.02m (which is 18011 events)
# 249.173851
# Duration: 2.00s (which is 11257 events)
# Distance: 23.15m (which is 11257 events)
# 256.889652
# Duration: 2.00s (which is 8450 events)
# Distance: 9.41m (which is 8450 events)
# 267.121412
# Duration: 2.00s (which is 7151 events)
# Distance: 19.72m (which is 7151 events)
# 289.021072
# Duration: 2.00s (which is 5243 events)
# Distance: 6.57m (which is 5243 events)
# 327.996082
# Duration: 2.00s (which is 7425 events)
# Distance: 27.30m (which is 7425 events)
# 363.142912
# Duration: 2.00s (which is 15030 events)
# Distance: 28.22m (which is 15030 events)
# 370.237614
# Duration: 2.00s (which is 11479 events)
# Distance: 29.24m (which is 11479 events)
# 377.208173
# Duration: 2.00s (which is 26435 events)
# Distance: 30.27m (which is 26435 events)
# 384.027906
# Duration: 2.00s (which is 23262 events)
# Distance: 30.40m (which is 23262 events)
# 390.686504
# Duration: 2.00s (which is 26455 events)
# Distance: 29.91m (which is 26455 events)
# 397.11738
# Duration: 2.00s (which is 12309 events)
# Distance: 29.23m (which is 12309 events)
# 404.122658
# Duration: 2.00s (which is 27836 events)
# Distance: 28.12m (which is 27836 events)
# 411.04103
# The number of training substreams is: 45
# Loading testing event streams ...
# Adding GPS
# Duration: 360.22s (which is 3433498 events)
# Distance: 4895.82m (which is 3433498 events)
# 14.27
# Duration: 2.00s (which is 17267 events)
# Distance: 28.54m (which is 17267 events)
# 21.47
# Duration: 2.00s (which is 10888 events)
# Distance: 21.99m (which is 10888 events)
# 36.85
# Duration: 2.00s (which is 10991 events)
# Distance: 23.60m (which is 10991 events)
# 44.66
# Duration: 2.00s (which is 18412 events)
# Distance: 26.33m (which is 18412 events)
# 52.41
# Duration: 2.00s (which is 23771 events)
# Distance: 28.09m (which is 23771 events)
# 59.29
# Duration: 2.00s (which is 17329 events)
# Distance: 28.92m (which is 17329 events)
# 66.22
# Duration: 2.00s (which is 15983 events)
# Distance: 27.98m (which is 15983 events)
# 75.39
# Duration: 2.00s (which is 18816 events)
# Distance: 14.35m (which is 18816 events)
# 85.82
# Duration: 2.00s (which is 31380 events)
# Distance: 26.06m (which is 31380 events)
# 93.15
# Duration: 2.00s (which is 26519 events)
# Distance: 28.65m (which is 26519 events)
# 99.91
# Duration: 2.00s (which is 36946 events)
# Distance: 30.20m (which is 36946 events)
# 106.57
# Duration: 2.00s (which is 26050 events)
# Distance: 30.44m (which is 26050 events)
# 113.1
# Duration: 2.00s (which is 42041 events)
# Distance: 29.92m (which is 42041 events)
# 119.79
# Duration: 2.00s (which is 38696 events)
# Distance: 30.49m (which is 38696 events)
# 126.32
# Duration: 2.00s (which is 41576 events)
# Distance: 31.00m (which is 41576 events)
# 132.8
# Duration: 2.00s (which is 33599 events)
# Distance: 31.40m (which is 33599 events)
# 139.4
# Duration: 2.00s (which is 12376 events)
# Distance: 25.71m (which is 12376 events)
# 148.86
# Duration: 2.00s (which is 4714 events)
# Distance: 27.86m (which is 4714 events)
# 155.17
# /home/n10223622/snn-event-vpr/src/BrisbaneVPRDatasetTime.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chopped_stream['t'] -= chop_start
# Duration: 2.00s (which is 15250 events)
# Distance: 34.88m (which is 15250 events)
# 160.86
# Duration: 2.00s (which is 7105 events)
# Distance: 35.18m (which is 7105 events)
# 166.58
# Duration: 2.00s (which is 5727 events)
# Distance: 35.82m (which is 5727 events)
# 172.16
# Duration: 2.00s (which is 5862 events)
# Distance: 35.70m (which is 5862 events)
# 177.0
# Duration: 2.00s (which is 4515 events)
# Distance: 35.92m (which is 4515 events)
# 183.42
# Duration: 2.00s (which is 7210 events)
# Distance: 33.21m (which is 7210 events)
# 189.55
# Duration: 2.00s (which is 4834 events)
# Distance: 33.28m (which is 4834 events)
# 195.57
# Duration: 2.00s (which is 9555 events)
# Distance: 32.24m (which is 9555 events)
# 202.19
# Duration: 2.00s (which is 30303 events)
# Distance: 28.69m (which is 30303 events)
# 209.05
# Duration: 2.00s (which is 11636 events)
# Distance: 29.58m (which is 11636 events)
# 215.78
# Duration: 2.00s (which is 21755 events)
# Distance: 30.14m (which is 21755 events)
# 222.4
# Duration: 2.00s (which is 25120 events)
# Distance: 30.60m (which is 25120 events)
# 228.79
# Duration: 2.00s (which is 21021 events)
# Distance: 32.72m (which is 21021 events)
# 234.91
# Duration: 2.00s (which is 33437 events)
# Distance: 30.90m (which is 33437 events)
# 241.6
# Duration: 2.00s (which is 25681 events)
# Distance: 28.81m (which is 25681 events)
# 249.6
# Duration: 2.00s (which is 15783 events)
# Distance: 22.48m (which is 15783 events)
# 258.01
# Duration: 2.00s (which is 18853 events)
# Distance: 23.71m (which is 18853 events)
# 266.56
# Duration: 2.00s (which is 9543 events)
# Distance: 22.60m (which is 9543 events)
# 284.44
# Duration: 2.00s (which is 13974 events)
# Distance: 18.14m (which is 13974 events)
# 293.31
# Duration: 2.00s (which is 16877 events)
# Distance: 27.75m (which is 16877 events)
# 300.27
# Duration: 2.00s (which is 29508 events)
# Distance: 29.30m (which is 29508 events)
# 307.09
# Duration: 2.00s (which is 15214 events)
# Distance: 29.93m (which is 15214 events)
# 313.61
# Duration: 2.00s (which is 42739 events)
# Distance: 31.10m (which is 42739 events)
# 320.19
# Duration: 2.00s (which is 26815 events)
# Distance: 31.12m (which is 26815 events)
# 326.65
# Duration: 2.00s (which is 31720 events)
# Distance: 30.18m (which is 31720 events)
# 333.51
# Duration: 2.00s (which is 19371 events)
# Distance: 28.90m (which is 19371 events)
# 340.49
# Duration: 2.00s (which is 32050 events)
# Distance: 28.34m (which is 32050 events)
# The number of testing substreams is: 45

# %%
# Define an optimiser 
optimizer = torch.optim.Adam(net.parameters(), lr=0.001)

# Training the network
error = slayer.loss.SpikeRate(true_rate=0.2, false_rate=0.03, reduction='sum').to(device)

# Create a training assistant object
stats = slayer.utils.LearningStats()
assistant = slayer.utils.Assistant(net, error, optimizer, stats, classifier=slayer.classifier.Rate.predict)


if redo_plot:
    for i, (input, label) in enumerate(train_loader): # training loop
        output = assistant.train(input, label)

else: 
    for epoch in range(epochs):

        for i, (input, label) in enumerate(train_loader): # training loop
            output = assistant.train(input, label)
        print(f'\r[Epoch {epoch:2d}/{epochs}] {stats}', end='')

        for i, (input, label) in enumerate(test_loader): # training loop
            output = assistant.test(input, label)
        print(f'\r[Epoch {epoch:2d}/{epochs}] {stats}', end='')

        if epoch%20 == 19: # cleanup display
            print('\r', ' '*len(f'\r[Epoch {epoch:2d}/{epochs}] {stats}'))
            stats_str = str(stats).replace("| ", "\n")
            print(f'[Epoch {epoch:2d}/{epochs}]\n{stats_str}')

        if stats.testing.best_accuracy:
            torch.save(net.state_dict(), trained_folder + '/network.pt')
        stats.update()
        stats.save(trained_folder + '/')
        net.grad_flow(trained_folder + '/')
# Out:
# [Epoch  0/50] Train loss =     0.85398 | Test  loss =     0.92640                        accuracy = 0.04444
# Accuracy was none
#
# Accuracy was none
# [Epoch  1/50] Train loss =     0.70264 (min =     0.85398)    accuracy = 0.08889  | Test  loss =     0.94178 (min =     0.92640)    accuracy = 0.04444 (max = 0.04444)
# Accuracy was none
# [Epoch  2/50] Train loss =     0.61741 (min =     0.70264)    accuracy = 0.06667 (max = 0.08889) | Test  loss =     0.79696 (min =     0.92640)    accuracy = 0.15556 (max = 0.04444)
# Accuracy was none
# [Epoch  3/50] Train loss =     0.49544 (min =     0.61741)    accuracy = 0.13333 (max = 0.08889) | Test  loss =     1.00658 (min =     0.79696)    accuracy = 0.17778 (max = 0.15556)
# Accuracy was none
# [Epoch  4/50] Train loss =     0.49419 (min =     0.49544)    accuracy = 0.28889 (max = 0.13333) | Test  loss =     1.03206 (min =     0.79696)    accuracy = 0.15556 (max = 0.17778)
# Accuracy was none
# [Epoch  5/50] Train loss =     0.51288 (min =     0.49419)    accuracy = 0.33333 (max = 0.28889) | Test  loss =     0.52504 (min =     0.79696)    accuracy = 0.17778 (max = 0.17778)
# Accuracy was none
# [Epoch  6/50] Train loss =     0.40787 (min =     0.49419)    accuracy = 0.35556 (max = 0.33333) | Test  loss =     1.49131 (min =     0.52504)    accuracy = 0.13333 (max = 0.17778)
# Accuracy was none
# [Epoch  7/50] Train loss =     0.44753 (min =     0.40787)    accuracy = 0.37778 (max = 0.35556) | Test  loss =     0.51575 (min =     0.52504)    accuracy = 0.28889 (max = 0.17778)
# Accuracy was none
# [Epoch  8/50] Train loss =     0.37657 (min =     0.40787)    accuracy = 0.55556 (max = 0.37778) | Test  loss =     0.75876 (min =     0.51575)    accuracy = 0.35556 (max = 0.28889)
# Accuracy was none
# [Epoch  9/50] Train loss =     0.34810 (min =     0.37657)    accuracy = 0.68889 (max = 0.55556) | Test  loss =     0.54948 (min =     0.51575)    accuracy = 0.37778 (max = 0.35556)
# Accuracy was none
# [Epoch 10/50] Train loss =     0.32913 (min =     0.34810)    accuracy = 0.73333 (max = 0.68889) | Test  loss =     0.57936 (min =     0.51575)    accuracy = 0.55556 (max = 0.37778)
# Accuracy was none
# [Epoch 11/50] Train loss =     0.28776 (min =     0.32913)    accuracy = 0.73333 (max = 0.73333) | Test  loss =     0.66590 (min =     0.51575)    accuracy = 0.57778 (max = 0.55556)
# Accuracy was none
# [Epoch 12/50] Train loss =     0.27244 (min =     0.28776)    accuracy = 0.75556 (max = 0.73333) | Test  loss =     0.53347 (min =     0.51575)    accuracy = 0.60000 (max = 0.57778)
# Accuracy was none
# [Epoch 13/50] Train loss =     0.26397 (min =     0.27244)    accuracy = 0.84444 (max = 0.75556) | Test  loss =     0.57227 (min =     0.51575)    accuracy = 0.73333 (max = 0.60000)
# Accuracy was none
# [Epoch 14/50] Train loss =     0.22981 (min =     0.26397)    accuracy = 0.86667 (max = 0.84444) | Test  loss =     0.66534 (min =     0.51575)    accuracy = 0.73333 (max = 0.73333)
# Accuracy was none
# [Epoch 15/50] Train loss =     0.21851 (min =     0.22981)    accuracy = 0.91111 (max = 0.86667) | Test  loss =     0.53658 (min =     0.51575)    accuracy = 0.68889 (max = 0.73333)
# Accuracy was none
# [Epoch 16/50] Train loss =     0.21242 (min =     0.21851)    accuracy = 0.95556 (max = 0.91111) | Test  loss =     0.45540 (min =     0.51575)    accuracy = 0.64444 (max = 0.73333)
# Accuracy was none
# [Epoch 17/50] Train loss =     0.19248 (min =     0.21242)    accuracy = 0.91111 (max = 0.95556) | Test  loss =     0.53199 (min =     0.45540)    accuracy = 0.77778 (max = 0.73333)
# Accuracy was none
# [Epoch 18/50] Train loss =     0.17878 (min =     0.19248)    accuracy = 0.95556 (max = 0.95556) | Test  loss =     0.42205 (min =     0.45540)    accuracy = 0.68889 (max = 0.77778)
# Accuracy was none
#
# [Epoch 19/50]
# Train loss =     0.16713 (min =     0.17878)    accuracy = 0.97778 (max = 0.95556)
# Test  loss =     0.65118 (min =     0.42205)    accuracy = 0.84444 (max = 0.77778)
#
# Accuracy was none
# [Epoch 20/50] Train loss =     0.16682 (min =     0.16713)    accuracy = 0.95556 (max = 0.97778) | Test  loss =     0.43425 (min =     0.42205)    accuracy = 0.82222 (max = 0.84444)
# Accuracy was none
# [Epoch 21/50] Train loss =     0.14504 (min =     0.16682)    accuracy = 0.93333 (max = 0.97778) | Test  loss =     0.45176 (min =     0.42205)    accuracy = 0.75556 (max = 0.84444)
# Accuracy was none
# [Epoch 22/50] Train loss =     0.13787 (min =     0.14504)    accuracy = 0.97778 (max = 0.97778) | Test  loss =     0.48119 (min =     0.42205)    accuracy = 0.80000 (max = 0.84444)
# Accuracy was none
# [Epoch 23/50] Train loss =     0.12807 (min =     0.13787)    accuracy = 1.00000 (max = 0.97778) | Test  loss =     0.50346 (min =     0.42205)    accuracy = 0.82222 (max = 0.84444)
# Accuracy was none
# [Epoch 24/50] Train loss =     0.11286 (min =     0.12807)    accuracy = 0.97778 (max = 1.00000) | Test  loss =     0.55370 (min =     0.42205)    accuracy = 0.84444 (max = 0.84444)
# Accuracy was none
# [Epoch 25/50] Train loss =     0.10886 (min =     0.11286)    accuracy = 0.97778 (max = 1.00000) | Test  loss =     0.46414 (min =     0.42205)    accuracy = 0.84444 (max = 0.84444)
# Accuracy was none
# [Epoch 26/50] Train loss =     0.10589 (min =     0.10886)    accuracy = 0.97778 (max = 1.00000) | Test  loss =     0.71610 (min =     0.42205)    accuracy = 0.84444 (max = 0.84444)
# Accuracy was none
# [Epoch 27/50] Train loss =     0.11888 (min =     0.10589)    accuracy = 0.97778 (max = 1.00000) | Test  loss =     0.65812 (min =     0.42205)    accuracy = 0.82222 (max = 0.84444)
# Accuracy was none
# [Epoch 28/50] Train loss =     0.10217 (min =     0.10589)    accuracy = 0.97778 (max = 1.00000) | Test  loss =     0.61455 (min =     0.42205)    accuracy = 0.84444 (max = 0.84444)
# Accuracy was none
# [Epoch 29/50] Train loss =     0.09063 (min =     0.10217)    accuracy = 0.97778 (max = 1.00000) | Test  loss =     0.43250 (min =     0.42205)    accuracy = 0.88889 (max = 0.84444)
# Accuracy was none
# [Epoch 30/50] Train loss =     0.08722 (min =     0.09063)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.51017 (min =     0.42205)    accuracy = 0.88889 (max = 0.88889)
# Accuracy was none
# [Epoch 31/50] Train loss =     0.08891 (min =     0.08722)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.56702 (min =     0.42205)    accuracy = 0.88889 (max = 0.88889)
# Accuracy was none
# [Epoch 32/50] Train loss =     0.07802 (min =     0.08722)    accuracy = 0.97778 (max = 1.00000) | Test  loss =     0.47539 (min =     0.42205)    accuracy = 0.95556 (max = 0.88889)
# Accuracy was none
# [Epoch 33/50] Train loss =     0.07728 (min =     0.07802)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.38357 (min =     0.42205)    accuracy = 0.82222 (max = 0.95556)
# Accuracy was none
# [Epoch 34/50] Train loss =     0.08427 (min =     0.07728)    accuracy = 0.97778 (max = 1.00000) | Test  loss =     0.41650 (min =     0.38357)    accuracy = 0.86667 (max = 0.95556)
# Accuracy was none
# [Epoch 35/50] Train loss =     0.07529 (min =     0.07728)    accuracy = 0.97778 (max = 1.00000) | Test  loss =     1.21216 (min =     0.38357)    accuracy = 0.86667 (max = 0.95556)
# Accuracy was none
# [Epoch 36/50] Train loss =     0.10911 (min =     0.07529)    accuracy = 0.97778 (max = 1.00000) | Test  loss =     0.28919 (min =     0.38357)    accuracy = 0.86667 (max = 0.95556)
# Accuracy was none
# [Epoch 37/50] Train loss =     0.11726 (min =     0.07529)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.31969 (min =     0.28919)    accuracy = 0.86667 (max = 0.95556)
# Accuracy was none
# [Epoch 38/50] Train loss =     0.11260 (min =     0.07529)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     1.10476 (min =     0.28919)    accuracy = 0.82222 (max = 0.95556)
# Accuracy was none
#
# [Epoch 39/50]
# Train loss =     0.12748 (min =     0.07529)    accuracy = 1.00000 (max = 1.00000)
# Test  loss =     0.36385 (min =     0.28919)    accuracy = 0.86667 (max = 0.95556)
#
# Accuracy was none
# [Epoch 40/50] Train loss =     0.10567 (min =     0.07529)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.67535 (min =     0.28919)    accuracy = 0.86667 (max = 0.95556)
# Accuracy was none
# [Epoch 41/50] Train loss =     0.08498 (min =     0.07529)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.50939 (min =     0.28919)    accuracy = 0.86667 (max = 0.95556)
# Accuracy was none
# [Epoch 42/50] Train loss =     0.07974 (min =     0.07529)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.47369 (min =     0.28919)    accuracy = 0.88889 (max = 0.95556)
# Accuracy was none
# [Epoch 43/50] Train loss =     0.07877 (min =     0.07529)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.62107 (min =     0.28919)    accuracy = 0.86667 (max = 0.95556)
# Accuracy was none
# [Epoch 44/50] Train loss =     0.07075 (min =     0.07529)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.42430 (min =     0.28919)    accuracy = 0.84444 (max = 0.95556)
# Accuracy was none
# [Epoch 45/50] Train loss =     0.06104 (min =     0.07075)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.35092 (min =     0.28919)    accuracy = 0.86667 (max = 0.95556)
# Accuracy was none
# [Epoch 46/50] Train loss =     0.05428 (min =     0.06104)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.59057 (min =     0.28919)    accuracy = 0.84444 (max = 0.95556)
# Accuracy was none
# [Epoch 47/50] Train loss =     0.05423 (min =     0.05428)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.39893 (min =     0.28919)    accuracy = 0.88889 (max = 0.95556)
# Accuracy was none
# [Epoch 48/50] Train loss =     0.05662 (min =     0.05423)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.48365 (min =     0.28919)    accuracy = 0.88889 (max = 0.95556)
# Accuracy was none
# [Epoch 49/50] Train loss =     0.04607 (min =     0.05423)    accuracy = 1.00000 (max = 1.00000) | Test  loss =     0.44955 (min =     0.28919)    accuracy = 0.86667 (max = 0.95556)
# Accuracy was none

# %%
# import the best network during training 
net.load_state_dict(torch.load(trained_folder + '/network.pt'))
net.export_hdf5(trained_folder + '/network.net')

# Get the output for the input to each place
test_loader2  = DataLoader(dataset=testing_set , batch_size=batch_size, shuffle=False)
rate = []
labels = []
for i, (input, label) in enumerate(test_loader2):
    output = net(input.to(device)) # Get network output
    #guesses = assistant.classifier(output).cpu().data.numpy() # get the predictions 
    rate.extend(Rate.rate(output).cpu().data.numpy()) # Get the firing rates for each place 
    labels.extend(label.cpu().data.numpy()) # Get place labels


# # Get rates in percentages of total
# for i in range(num_places):
#     sum = np.sum(rate[i])
#     if sum != 0:
#         rate[i] = np.divide(rate[i],sum)

# Make confusion matrix annotations
accuracy = 0
matches = []
annotations = [['' for i in range(num_places)] for j in range(num_places)]
for qryIndex in range(num_places):
    max_idx = np.argmax(rate[qryIndex])
    matches.append(max_idx)
    annotations[max_idx][qryIndex] = 'x'
    if max_idx ==qryIndex:
        accuracy += 1


#--------------- Apply a sequencer ------------------#
I = np.identity(sequence_length)
conv = signal.convolve2d(rate, I, mode='same')
print(np.shape(conv))

# Make confusion matrix annotations
accuracy_s = 0
matches_with_seq = []
annotations_s = [['' for i in range(num_places)] for j in range(num_places)]
for qryIndex in range(num_places):
    max_idx = np.argmax(conv[qryIndex])
    matches_with_seq.append(max_idx)
    annotations_s[max_idx][qryIndex] = 'x'
    if max_idx == qryIndex:
        accuracy_s += 1
# Out:
# (45, 45)

# %%
#--------------- Save Results ------------------#

# Make new folder for results
from tracemalloc import start
from plotting import plot_gps


time_stamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
results_path = "./../results/" + time_stamp
os.mkdir(results_path)


# Save query and match images 
images_path = results_path + "/matched_images"
images_path_seq = results_path + "/matched_images_seq"
os.mkdir(images_path)
os.mkdir(images_path_seq)

print('help')
plot_match_images(images_path + "/", matches, training_set.place_images, testing_set.place_images)
plot_match_images(images_path_seq + "/", matches_with_seq, training_set.place_images, testing_set.place_images)

# Save the confusion matrices
confusion_path = results_path + "/confusion_matrices"
os.mkdir(confusion_path)
rate = transpose(rate)
conv = transpose(conv)
output_path = confusion_path + "/confusion_matrix" 
output_path_s = confusion_path + "/confusion_matrix_seq" 
plot_confusion_matrix(rate, labels, annotations, output_path, vmin, vmax)
plot_confusion_matrix(conv, labels, annotations_s, output_path_s, vmin, vmax)

# Save GPS map'
gps_path = results_path + "/gps_locations"
plot_gps(gps_path, training_set.place_locations, testing_set.place_locations)

# Save test settings and accuracy
accuracy = accuracy/num_places
accuracy_s = accuracy_s/num_places
# Out:
# help

# %%
log_path = results_path + "/log.txt"
log_string  = """
---- DATA SETTINGS ---- 
Training datasets = {}
Testing datasets = {} 
# Places = {}
Start dist = {} [s]
Place gap = {} [s]
Place duration = {} [s]
Samples per second = {} 
Max spikes per sample = {}
---- NETWORK SETTINGS ---- 
Input size = {}x{} 
Threshold = {}
---- TRAINING SETTINGS ---- 
Epochs = {}
Batch size = {}
---- SEQUENCER SETTINGS ----
Sequence lengtth = {} 
---- RESULTS ----
Accuracy = {}
Accuracy (sequencer) = {}
""".format(train_name,test_name,num_places,start_dist,place_gap,place_duration,
                samples_per_sec,max_spikes,input_size,input_size,threshold,epochs,
                batch_size,sequence_length,accuracy,accuracy_s)
f = open(log_path,'w')
f.write(log_string)
f.close()

print("The accuracy of the network is: " + str(accuracy))
print("The accuracy with a sequencer is: " + str(accuracy_s))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb Cell 8 in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> log_path = results_path + "/log.txt"
#       <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> log_string  = """
#       <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> ---- DATA SETTINGS ----
#       <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> Training datasets = {}
#       <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> Testing datasets = {}
#       <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> # Places = {}
#       <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> Start time = {} [s]
#       <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> Place gap = {} [s]
#       <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> Place duration = {} [s]
#      <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> Samples per second = {}
#      <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> Max spikes per sample = {}
#      <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> ---- NETWORK SETTINGS ----
#      <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> Input size = {}x{}
#      <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> Threshold = {}
#      <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> ---- TRAINING SETTINGS ----
#      <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> Epochs = {}
#      <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> Batch size = {}
#      <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a> ---- SEQUENCER SETTINGS ----
#      <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> Sequence lengtth = {}
#      <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a> ---- RESULTS ----
#      <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a> Accuracy = {}
#      <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a> Accuracy (sequencer) = {}
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a> """.format(train_name,test_name,num_places,start_time,place_gap,place_duration,
#      <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>                 samples_per_sec,max_spikes,input_size,input_size,threshold,epochs,
#      <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a>                 batch_size,sequence_length,accuracy,accuracy_s)
#      <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a> f = open(log_path,'w')
#      <a href='vscode-notebook-cell://ssh-remote%2Bvenus.qut.edu.au/home/n10223622/snn-event-vpr/src/software_pipeline_time.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a> f.write(log_string)
#
# NameError: name 'start_time' is not defined
